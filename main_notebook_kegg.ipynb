# %%
import shutil, os
if os.path.exists('/content/project'):
    shutil.rmtree('/content/project')
# !git clone https://github.com/TruongDuyLongPTIT/CTQW-PRO-Quantum-Walk-Based-Metabolite-Disease-Prioritization.git /content/project

# Add src vào Python path
import sys
sys.path.insert(0, '/content/project/src')

# Install dependencies
# !pip install -q torch scikit-learn networkx tqdm
# Out:
# Cloning into '/content/project'...
# remote: Enumerating objects: 507, done.
# remote: Counting objects: 100% (304/304), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 507 (delta 201), reused 151 (delta 73), pack-reused 203 (from 1)
# Receiving objects: 100% (507/507), 1.30 MiB | 6.40 MiB/s, done.
# Resolving deltas: 100% (321/321), done.

# %%
from pathlib import Path
from google.colab import drive

if not Path('/content/drive/MyDrive').exists():
    drive.mount('/content/drive')
else:
    print("Drive đã mount sẵn.")
# Out:
# Mounted at /content/drive

# %%
# !python /content/project/experiments/01_main_results_kegg.py
# Out:
# ============================================================
# STEP 1 — Build graph (KEGG)
# Lấy danh sách pathway chuyển hóa ở người (BRITE br08901 ∩ hsa)...
#   86 pathway (đã loại overview/chemical-structure maps)
# Lấy reaction id theo từng pathway (link/rn/mapNNNNN)...
#     20/86 pathway...
#     40/86 pathway...
#     60/86 pathway...
#     80/86 pathway...
#   4497 reaction id duy nhất (hợp của mọi pathway)
# Lấy EQUATION cho từng reaction (batch 10, get/rn:...+rn:...)...
#     equations: 20/450 batch...
#     equations: 40/450 batch...
#     equations: 60/450 batch...
#     equations: 80/450 batch...
#     equations: 100/450 batch...
#     equations: 120/450 batch...
#     equations: 140/450 batch...
#     equations: 160/450 batch...
#     equations: 180/450 batch...
#     equations: 200/450 batch...
#     equations: 220/450 batch...
#     equations: 240/450 batch...
#     equations: 260/450 batch...
#     equations: 280/450 batch...
#     equations: 300/450 batch...
#     equations: 320/450 batch...
#     equations: 340/450 batch...
#     equations: 360/450 batch...
#     equations: 380/450 batch...
#     equations: 400/450 batch...
#     equations: 420/450 batch...
#     equations: 440/450 batch...
#   4317/4497 reaction có EQUATION parse được
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Graph: 3050 nodes, 18848 edges
#   G_pro: 3129 nodes (79 pathway), 24655 edges
#
# STEP 2 — Build eval sets
# Parsing HMDB (~10-20 phút, cần quét lại để lấy thêm field kegg_id)...
#   Done in 4.3 phut, 217920 metabolite
#   CTD parsed in 12.8s
#   Parsed 1090 markers in 0.8s
#   Extracting SMPDB metabolites...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:25<00:00, 1942.49it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   eval_set1 (HMDB+CTD): 310 diseases
#   eval_set2 (MarkerDB): 25 diseases
#   eval_set3 (SMPDB):    181 diseases
#   HMDB+CTD: 310 tên bệnh → 310 seed-set độc lập
#   MarkerDB: 25 tên bệnh → 25 seed-set độc lập
#   SMPDB: 181 tên bệnh → 50 seed-set độc lập
#
# STEP 3 — Eigendecomposition
#   eigh(3129×3129)...
#   Done in 5.9s
#   eigh(3050×3050)...
#   Done in 4.0s
#   Done.
#
# ============================================================
# [Table 1] RWR vs CTQW on G_cc (KEGG)...
# RWR/HMDB+CTD: 100% 310/310 [03:17<00:00,  1.57it/s]
# MetaboRank-lite/HMDB+CTD: 100% 310/310 [03:18<00:00,  1.56it/s]
# CTQW/HMDB+CTD: 100% 310/310 [01:36<00:00,  3.23it/s]
#   HMDB+CTD: 8.2 min
# RWR/MarkerDB: 100% 25/25 [00:23<00:00,  1.08it/s]
# MetaboRank-lite/MarkerDB: 100% 25/25 [00:21<00:00,  1.17it/s]
# CTQW/MarkerDB: 100% 25/25 [00:11<00:00,  2.16it/s]
#   MarkerDB: 0.9 min
# RWR/SMPDB: 100% 181/181 [01:47<00:00,  1.68it/s]
# MetaboRank-lite/SMPDB: 100% 181/181 [01:46<00:00,  1.70it/s]
# CTQW/SMPDB: 100% 181/181 [00:53<00:00,  3.38it/s]
#   SMPDB: 4.5 min
#
# [Table 2] PROFANCY vs CTQW-PRO on G_pro (KEGG)...
# PROFANCY/HMDB+CTD: 100% 310/310 [03:26<00:00,  1.50it/s]
# MetaboRank-lite-PRO/HMDB+CTD: 100% 310/310 [03:24<00:00,  1.52it/s]
# CTQW-PRO/HMDB+CTD: 100% 310/310 [01:39<00:00,  3.11it/s]
#   HMDB+CTD: 8.5 min
# PROFANCY/MarkerDB: 100% 25/25 [00:24<00:00,  1.03it/s]
# MetaboRank-lite-PRO/MarkerDB: 100% 25/25 [00:24<00:00,  1.02it/s]
# CTQW-PRO/MarkerDB: 100% 25/25 [00:11<00:00,  2.09it/s]
#   MarkerDB: 1.0 min
# PROFANCY/SMPDB: 100% 181/181 [01:50<00:00,  1.64it/s]
# MetaboRank-lite-PRO/SMPDB: 100% 181/181 [01:49<00:00,  1.65it/s]
# CTQW-PRO/SMPDB: 100% 181/181 [00:56<00:00,  3.18it/s]
#   SMPDB: 4.6 min
#
# [Table 3] NH-CTQW-PRO (KEGG)...
#   Building NH eigendecomp (γ=16.0)... 69.4s
# NH/HMDB+CTD: 100% 310/310 [01:44<00:00,  2.98it/s]
#   HMDB+CTD: 1.7 min
# NH/MarkerDB: 100% 25/25 [00:12<00:00,  2.07it/s]
#   MarkerDB: 0.2 min
# NH/SMPDB: 100% 181/181 [00:56<00:00,  3.18it/s]
#   SMPDB: 0.9 min
#
# ========================================================================
# TABLE 1: RWR vs MetaboRank-lite vs CTQW (G_cc, KEGG)
#
# === HMDB+CTD (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.7749   0.0097  0.0017  0.0137  0.0399
# MetaboRank-lite          0.7591   0.0184  0.0211  0.0361  0.0685 ◄
# CTQW                     0.7247   0.0245  0.0299  0.0479  0.0779 ◄
#
# === HMDB+CTD (dedup) (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.7749   0.0097  0.0017  0.0137  0.0399
# MetaboRank-lite          0.7591   0.0184  0.0211  0.0361  0.0685 ◄
# CTQW                     0.7247   0.0245  0.0299  0.0479  0.0779 ◄
#
# === MarkerDB (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.8483   0.0145  0.0000  0.0171  0.0847
# MetaboRank-lite          0.8454   0.0339  0.0479  0.0825  0.1417 ◄
# CTQW                     0.8027   0.0535  0.0517  0.1101  0.1757 ◄
#
# === MarkerDB (dedup) (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.8483   0.0145  0.0000  0.0171  0.0847
# MetaboRank-lite          0.8454   0.0339  0.0479  0.0825  0.1417 ◄
# CTQW                     0.8027   0.0535  0.0517  0.1101  0.1757 ◄
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.9523   0.0578  0.0526  0.1431  0.4183
# MetaboRank-lite          0.9480   0.1639  0.2457  0.3655  0.4601 ◄
# CTQW                     0.9381   0.2145  0.2844  0.4261  0.5360 ◄
#
# === SMPDB (dedup) (n=50) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.9518   0.0601  0.0558  0.1678  0.4239
# MetaboRank-lite          0.9475   0.1685  0.2394  0.3401  0.4454 ◄
# CTQW                     0.9350   0.2306  0.3062  0.4304  0.5355 ◄
#
# ========================================================================
# TABLE 2: PROFANCY vs MetaboRank-lite-PRO vs CTQW-PRO (G_pro, KEGG)
#
# === HMDB+CTD (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8120   0.0101  0.0011  0.0134  0.0396
# MetaboRank-lite-PRO      0.8067   0.0198  0.0222  0.0371  0.0708 ◄
# t=0.1                    0.7740   0.0270  0.0307  0.0510  0.0818 ◄
#
# === HMDB+CTD (dedup) (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8120   0.0101  0.0011  0.0134  0.0396
# MetaboRank-lite-PRO      0.8067   0.0198  0.0222  0.0371  0.0708 ◄
# t=0.1                    0.7740   0.0270  0.0307  0.0510  0.0818 ◄
#
# === MarkerDB (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8538   0.0159  0.0050  0.0171  0.0795
# MetaboRank-lite-PRO      0.8516   0.0354  0.0447  0.0866  0.1432 ◄
# t=0.1                    0.8254   0.0537  0.0570  0.1176  0.1829 ◄
#
# === MarkerDB (dedup) (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8538   0.0159  0.0050  0.0171  0.0795
# MetaboRank-lite-PRO      0.8516   0.0354  0.0447  0.0866  0.1432 ◄
# t=0.1                    0.8254   0.0537  0.0570  0.1176  0.1829 ◄
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9559   0.0580  0.0526  0.1413  0.4078
# MetaboRank-lite-PRO      0.9530   0.1633  0.2481  0.3630  0.4660 ◄
# t=0.1                    0.9517   0.2040  0.2801  0.4330  0.5675 ◄
#
# === SMPDB (dedup) (n=50) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9554   0.0595  0.0558  0.1621  0.4124
# MetaboRank-lite-PRO      0.9524   0.1657  0.2398  0.3339  0.4491 ◄
# t=0.1                    0.9460   0.2217  0.3131  0.4346  0.5685 ◄
#
# ========================================================================
# TABLE 3: CTQW-PRO vs NH-CTQW-PRO (G_pro, KEGG)
#
# === HMDB+CTD (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.7740   0.0270  0.0307  0.0510  0.0818
# NH γ=16.0                0.7883   0.0295  0.0353  0.0595  0.0916 ◄
#
# === HMDB+CTD (dedup) (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.7740   0.0270  0.0307  0.0510  0.0818
# NH γ=16.0                0.7883   0.0295  0.0353  0.0595  0.0916 ◄
#
# === MarkerDB (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8254   0.0537  0.0570  0.1176  0.1829
# NH γ=16.0                0.8324   0.0569  0.0628  0.1284  0.1988 ◄
#
# === MarkerDB (dedup) (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8254   0.0537  0.0570  0.1176  0.1829
# NH γ=16.0                0.8324   0.0569  0.0628  0.1284  0.1988 ◄
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.9517   0.2040  0.2801  0.4330  0.5675
# NH γ=16.0                0.9533   0.2369  0.3255  0.4946  0.6157 ◄
#
# === SMPDB (dedup) (n=50) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.9460   0.2217  0.3131  0.4346  0.5685
# NH γ=16.0                0.9491   0.2546  0.3546  0.4846  0.6074 ◄
#
# ========================================================================
# WILCOXON: CTQW vs RWR
#
# --- HMDB+CTD (n=310) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.7749+/-0.0924   0.7247+/-0.1108  -0.0502  1.648e-33  ***
#   mrr        0.0097+/-0.0104   0.0245+/-0.0462  +0.0148  6.856e-09  ***
#   r@5        0.0017+/-0.0130   0.0299+/-0.0732  +0.0282   2.73e-12  ***
#   r@10       0.0137+/-0.0415   0.0479+/-0.1010  +0.0343  3.051e-12  ***
#   r@20       0.0399+/-0.0849   0.0779+/-0.1313  +0.0380   2.82e-13  ***
#
# --- MarkerDB (n=25) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.8483+/-0.0805   0.8027+/-0.1058  -0.0456  0.0001907  ***
#   mrr        0.0145+/-0.0083   0.0535+/-0.0579  +0.0390  9.835e-06  ***
#   r@5        0.0000+/-0.0000   0.0517+/-0.0628  +0.0517   0.004795  **
#   r@10       0.0171+/-0.0396   0.1101+/-0.1019  +0.0930  0.0009617  ***
#   r@20       0.0847+/-0.0840   0.1757+/-0.1309  +0.0911  0.0006581  ***
#
# --- SMPDB (n=181) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.9523+/-0.0273   0.9381+/-0.0358  -0.0142  1.461e-18  ***
#   mrr        0.0578+/-0.0441   0.2145+/-0.1389  +0.1566  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.2844+/-0.1893  +0.2318  8.765e-30  ***
#   r@10       0.1431+/-0.1557   0.4261+/-0.1723  +0.2830  6.985e-29  ***
#   r@20       0.4183+/-0.1719   0.5360+/-0.1577  +0.1177  3.811e-22  ***
#
# WILCOXON: CTQW-PRO vs PROFANCY
#
# --- HMDB+CTD (n=310) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7740+/-0.0932  -0.0380  7.522e-27  ***
#   mrr        0.0101+/-0.0102   0.0270+/-0.0523  +0.0169  1.739e-12  ***
#   r@5        0.0011+/-0.0104   0.0307+/-0.0813  +0.0296  3.773e-12  ***
#   r@10       0.0134+/-0.0393   0.0510+/-0.1053  +0.0376  5.355e-13  ***
#   r@20       0.0396+/-0.0852   0.0818+/-0.1345  +0.0422  3.014e-14  ***
#
# --- MarkerDB (n=25) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8538+/-0.0838   0.8254+/-0.0972  -0.0284   0.005136  **
#   mrr        0.0159+/-0.0107   0.0537+/-0.0567  +0.0378  2.086e-05  ***
#   r@5        0.0050+/-0.0245   0.0570+/-0.0728  +0.0520    0.01087  *
#   r@10       0.0171+/-0.0396   0.1176+/-0.1297  +0.1005   0.000977  ***
#   r@20       0.0795+/-0.0853   0.1829+/-0.1570  +0.1034   0.002407  **
#
# --- SMPDB (n=181) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9517+/-0.0340  -0.0042     0.8002  ns
#   mrr        0.0580+/-0.0467   0.2040+/-0.1265  +0.1461  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.2801+/-0.1769  +0.2275  8.103e-28  ***
#   r@10       0.1413+/-0.1538   0.4330+/-0.1745  +0.2917  1.226e-28  ***
#   r@20       0.4078+/-0.1718   0.5675+/-0.1497  +0.1597  9.114e-27  ***
#
# WILCOXON: MetaboRank-lite vs RWR (G_cc)
#
# --- HMDB+CTD (n=310) ---
#   Metric                RWR  MetaboRank-lite    Delta     p_bonf  Sig
#   auc        0.7749+/-0.0924   0.7591+/-0.0989  -0.0158  2.163e-39  ***
#   mrr        0.0097+/-0.0104   0.0184+/-0.0323  +0.0087  1.717e-14  ***
#   r@5        0.0017+/-0.0130   0.0211+/-0.0563  +0.0194  4.963e-11  ***
#   r@10       0.0137+/-0.0415   0.0361+/-0.0777  +0.0224  4.532e-10  ***
#   r@20       0.0399+/-0.0849   0.0685+/-0.1146  +0.0286  7.315e-11  ***
#
# --- MarkerDB (n=25) ---
#   Metric                RWR  MetaboRank-lite    Delta     p_bonf  Sig
#   auc        0.8483+/-0.0805   0.8454+/-0.0807  -0.0028     0.3549  ns
#   mrr        0.0145+/-0.0083   0.0339+/-0.0323  +0.0194   0.001645  **
#   r@5        0.0000+/-0.0000   0.0479+/-0.0727  +0.0479    0.01673  *
#   r@10       0.0171+/-0.0396   0.0825+/-0.0864  +0.0654    0.01572  *
#   r@20       0.0847+/-0.0840   0.1417+/-0.1260  +0.0570    0.07492  .
#
# --- SMPDB (n=181) ---
#   Metric                RWR  MetaboRank-lite    Delta     p_bonf  Sig
#   auc        0.9523+/-0.0273   0.9480+/-0.0285  -0.0043  5.847e-20  ***
#   mrr        0.0578+/-0.0441   0.1639+/-0.0852  +0.1061  2.617e-29  ***
#   r@5        0.0526+/-0.1008   0.2457+/-0.1193  +0.1930  1.389e-25  ***
#   r@10       0.1431+/-0.1557   0.3655+/-0.1559  +0.2224  1.604e-24  ***
#   r@20       0.4183+/-0.1719   0.4601+/-0.1741  +0.0418   0.007696  **
#
# WILCOXON: CTQW vs MetaboRank-lite (G_cc)
#
# --- HMDB+CTD (n=310) ---
#   Metric    MetaboRank-lite             CTQW    Delta     p_bonf  Sig
#   auc        0.7591+/-0.0989   0.7247+/-0.1108  -0.0344  4.108e-20  ***
#   mrr        0.0184+/-0.0323   0.0245+/-0.0462  +0.0061          1  ns
#   r@5        0.0211+/-0.0563   0.0299+/-0.0732  +0.0088     0.1385  ns
#   r@10       0.0361+/-0.0777   0.0479+/-0.1010  +0.0119    0.04516  *
#   r@20       0.0685+/-0.1146   0.0779+/-0.1313  +0.0094      0.452  ns
#
# --- MarkerDB (n=25) ---
#   Metric    MetaboRank-lite             CTQW    Delta     p_bonf  Sig
#   auc        0.8454+/-0.0807   0.8027+/-0.1058  -0.0428  0.0004402  ***
#   mrr        0.0339+/-0.0323   0.0535+/-0.0579  +0.0196          1  ns
#   r@5        0.0479+/-0.0727   0.0517+/-0.0628  +0.0037          1  ns
#   r@10       0.0825+/-0.0864   0.1101+/-0.1019  +0.0276     0.5432  ns
#   r@20       0.1417+/-0.1260   0.1757+/-0.1309  +0.0341          1  ns
#
# --- SMPDB (n=181) ---
#   Metric    MetaboRank-lite             CTQW    Delta     p_bonf  Sig
#   auc        0.9480+/-0.0285   0.9381+/-0.0358  -0.0100  1.966e-10  ***
#   mrr        0.1639+/-0.0852   0.2145+/-0.1389  +0.0505  0.0004004  ***
#   r@5        0.2457+/-0.1193   0.2844+/-0.1893  +0.0388          1  ns
#   r@10       0.3655+/-0.1559   0.4261+/-0.1723  +0.0606    0.01094  *
#   r@20       0.4601+/-0.1741   0.5360+/-0.1577  +0.0759  7.646e-08  ***
#
# WILCOXON: MetaboRank-lite-PRO vs PROFANCY (G_pro)
#
# --- HMDB+CTD (n=310) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.8067+/-0.0864  -0.0053  2.901e-14  ***
#   mrr        0.0101+/-0.0102   0.0198+/-0.0344  +0.0097  2.092e-18  ***
#   r@5        0.0011+/-0.0104   0.0222+/-0.0561  +0.0211  1.275e-12  ***
#   r@10       0.0134+/-0.0393   0.0371+/-0.0796  +0.0236  3.671e-10  ***
#   r@20       0.0396+/-0.0852   0.0708+/-0.1165  +0.0312  2.334e-12  ***
#
# --- MarkerDB (n=25) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8538+/-0.0838   0.8516+/-0.0835  -0.0022     0.8225  ns
#   mrr        0.0159+/-0.0107   0.0354+/-0.0337  +0.0195   0.001882  **
#   r@5        0.0050+/-0.0245   0.0447+/-0.0616  +0.0397    0.09211  .
#   r@10       0.0171+/-0.0396   0.0866+/-0.0985  +0.0696    0.01714  *
#   r@20       0.0795+/-0.0853   0.1432+/-0.1165  +0.0637   0.008908  **
#
# --- SMPDB (n=181) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9530+/-0.0252  -0.0029  1.054e-13  ***
#   mrr        0.0580+/-0.0467   0.1633+/-0.0873  +0.1053  1.386e-29  ***
#   r@5        0.0526+/-0.1008   0.2481+/-0.1282  +0.1954  1.809e-25  ***
#   r@10       0.1413+/-0.1538   0.3630+/-0.1595  +0.2217  1.597e-24  ***
#   r@20       0.4078+/-0.1718   0.4660+/-0.1765  +0.0582  0.0007518  ***
#
# WILCOXON: CTQW-PRO vs MetaboRank-lite-PRO (G_pro)
#
# --- HMDB+CTD (n=310) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8067+/-0.0864   0.7740+/-0.0932  -0.0326  1.391e-21  ***
#   mrr        0.0198+/-0.0344   0.0270+/-0.0523  +0.0072     0.4014  ns
#   r@5        0.0222+/-0.0561   0.0307+/-0.0813  +0.0085      0.535  ns
#   r@10       0.0371+/-0.0796   0.0510+/-0.1053  +0.0139    0.03554  *
#   r@20       0.0708+/-0.1165   0.0818+/-0.1345  +0.0110     0.2854  ns
#
# --- MarkerDB (n=25) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8516+/-0.0835   0.8254+/-0.0972  -0.0263    0.01128  *
#   mrr        0.0354+/-0.0337   0.0537+/-0.0567  +0.0183     0.7424  ns
#   r@5        0.0447+/-0.0616   0.0570+/-0.0728  +0.0124          1  ns
#   r@10       0.0866+/-0.0985   0.1176+/-0.1297  +0.0310     0.8933  ns
#   r@20       0.1432+/-0.1165   0.1829+/-0.1570  +0.0397     0.6297  ns
#
# --- SMPDB (n=181) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9530+/-0.0252   0.9517+/-0.0340  -0.0013          1  ns
#   mrr        0.1633+/-0.0873   0.2040+/-0.1265  +0.0407   0.002131  **
#   r@5        0.2481+/-0.1282   0.2801+/-0.1769  +0.0320     0.9388  ns
#   r@10       0.3630+/-0.1595   0.4330+/-0.1745  +0.0700  7.119e-06  ***
#   r@20       0.4660+/-0.1765   0.5675+/-0.1497  +0.1015  2.474e-10  ***
#
# WILCOXON: NH vs CTQW-PRO
#
# --- HMDB+CTD (n=310) ---
#   Metric           CTQW-PRO        NH γ=16.0    Delta     p_bonf  Sig
#   auc        0.7740+/-0.0932   0.7883+/-0.0889  +0.0143  1.283e-29  ***
#   mrr        0.0270+/-0.0523   0.0295+/-0.0540  +0.0025  1.017e-33  ***
#   r@5        0.0307+/-0.0813   0.0353+/-0.0814  +0.0046  0.0003323  ***
#   r@10       0.0510+/-0.1053   0.0595+/-0.1176  +0.0085  4.493e-06  ***
#   r@20       0.0818+/-0.1345   0.0916+/-0.1366  +0.0098    5.5e-08  ***
#
# --- MarkerDB (n=25) ---
#   Metric           CTQW-PRO        NH γ=16.0    Delta     p_bonf  Sig
#   auc        0.8254+/-0.0972   0.8324+/-0.0977  +0.0071    0.02302  *
#   mrr        0.0537+/-0.0567   0.0569+/-0.0563  +0.0031  3.278e-05  ***
#   r@5        0.0570+/-0.0728   0.0628+/-0.0753  +0.0057     0.3394  ns
#   r@10       0.1176+/-0.1297   0.1284+/-0.1259  +0.0107     0.2156  ns
#   r@20       0.1829+/-0.1570   0.1988+/-0.1502  +0.0158    0.05859  .
#
# --- SMPDB (n=181) ---
#   Metric           CTQW-PRO        NH γ=16.0    Delta     p_bonf  Sig
#   auc        0.9517+/-0.0340   0.9533+/-0.0343  +0.0016   5.16e-05  ***
#   mrr        0.2040+/-0.1265   0.2369+/-0.1457  +0.0328  3.838e-28  ***
#   r@5        0.2801+/-0.1769   0.3255+/-0.1993  +0.0454  4.878e-14  ***
#   r@10       0.4330+/-0.1745   0.4946+/-0.1843  +0.0615  2.239e-18  ***
#   r@20       0.5675+/-0.1497   0.6157+/-0.1439  +0.0482  8.035e-18  ***
#
# WILCOXON CHÉO ĐỒ THỊ: PROFANCY (Gpro) vs RWR (Gcc)
#
# --- HMDB+CTD (n=310) ---
#   Metric                RWR         PROFANCY    Delta     p_bonf  Sig
#   auc        0.7749+/-0.0924   0.8120+/-0.0827  +0.0371  3.093e-35  ***
#   mrr        0.0097+/-0.0104   0.0101+/-0.0102  +0.0004  1.242e-16  ***
#   r@5        0.0017+/-0.0130   0.0011+/-0.0104  -0.0006     0.8986  ns
#   r@10       0.0137+/-0.0415   0.0134+/-0.0393  -0.0002          1  ns
#   r@20       0.0399+/-0.0849   0.0396+/-0.0852  -0.0003          1  ns
#
# --- MarkerDB (n=25) ---
#   Metric                RWR         PROFANCY    Delta     p_bonf  Sig
#   auc        0.8483+/-0.0805   0.8538+/-0.0838  +0.0055     0.7046  ns
#   mrr        0.0145+/-0.0083   0.0159+/-0.0107  +0.0014          1  ns
#   r@5        0.0000+/-0.0000   0.0050+/-0.0245  +0.0050          1  ns
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_wilcoxon.py:178: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
#   r@10       0.0171+/-0.0396   0.0171+/-0.0396  +0.0000        nan
#   r@20       0.0847+/-0.0840   0.0795+/-0.0853  -0.0051     0.8986  ns
#
# --- SMPDB (n=181) ---
#   Metric                RWR         PROFANCY    Delta     p_bonf  Sig
#   auc        0.9523+/-0.0273   0.9559+/-0.0239  +0.0036  5.899e-08  ***
#   mrr        0.0578+/-0.0441   0.0580+/-0.0467  +0.0001          1  ns
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_wilcoxon.py:178: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
#   r@5        0.0526+/-0.1008   0.0526+/-0.1008  +0.0000        nan
#   r@10       0.1431+/-0.1557   0.1413+/-0.1538  -0.0018          1  ns
#   r@20       0.4183+/-0.1719   0.4078+/-0.1718  -0.0105  0.0003366  ***
#
# WILCOXON CHÉO ĐỒ THỊ: CTQW-PRO (Gpro) vs CTQW (Gcc)
#
# --- HMDB+CTD (n=310) ---
#   Metric               CTQW         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7247+/-0.1108   0.7740+/-0.0932  +0.0493  9.596e-41  ***
#   mrr        0.0245+/-0.0462   0.0270+/-0.0523  +0.0024  1.831e-09  ***
#   r@5        0.0299+/-0.0732   0.0307+/-0.0813  +0.0008          1  ns
#   r@10       0.0479+/-0.1010   0.0510+/-0.1053  +0.0031     0.7296  ns
#   r@20       0.0779+/-0.1313   0.0818+/-0.1345  +0.0039       0.83  ns
#
# --- MarkerDB (n=25) ---
#   Metric               CTQW         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8027+/-0.1058   0.8254+/-0.0972  +0.0227   0.002447  **
#   mrr        0.0535+/-0.0579   0.0537+/-0.0567  +0.0002          1  ns
#   r@5        0.0517+/-0.0628   0.0570+/-0.0728  +0.0054          1  ns
#   r@10       0.1101+/-0.1019   0.1176+/-0.1297  +0.0075          1  ns
#   r@20       0.1757+/-0.1309   0.1829+/-0.1570  +0.0072          1  ns
#
# --- SMPDB (n=181) ---
#   Metric               CTQW         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9381+/-0.0358   0.9517+/-0.0340  +0.0137   1.13e-17  ***
#   mrr        0.2145+/-0.1389   0.2040+/-0.1265  -0.0104    0.09138  .
#   r@5        0.2844+/-0.1893   0.2801+/-0.1769  -0.0043          1  ns
#   r@10       0.4261+/-0.1723   0.4330+/-0.1745  +0.0069          1  ns
#   r@20       0.5360+/-0.1577   0.5675+/-0.1497  +0.0315  2.019e-12  ***
#
# WILCOXON CHÉO ĐỒ THỊ: MetaboRank-lite-PRO (Gpro) vs MetaboRank-lite (Gcc)
#
# --- HMDB+CTD (n=310) ---
#   Metric    MetaboRank-lite MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.7591+/-0.0989   0.8067+/-0.0864  +0.0476  1.382e-39  ***
#   mrr        0.0184+/-0.0323   0.0198+/-0.0344  +0.0014  2.839e-25  ***
#   r@5        0.0211+/-0.0563   0.0222+/-0.0561  +0.0011     0.4175  ns
#   r@10       0.0361+/-0.0777   0.0371+/-0.0796  +0.0010     0.7932  ns
#   r@20       0.0685+/-0.1146   0.0708+/-0.1165  +0.0023     0.2075  ns
#
# --- MarkerDB (n=25) ---
#   Metric    MetaboRank-lite MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8454+/-0.0807   0.8516+/-0.0835  +0.0062    0.09372  .
#   mrr        0.0339+/-0.0323   0.0354+/-0.0337  +0.0015    0.05255  .
#   r@5        0.0479+/-0.0727   0.0447+/-0.0616  -0.0033          1  ns
#   r@10       0.0825+/-0.0864   0.0866+/-0.0985  +0.0041          1  ns
#   r@20       0.1417+/-0.1260   0.1432+/-0.1165  +0.0015          1  ns
#
# --- SMPDB (n=181) ---
#   Metric    MetaboRank-lite MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.9480+/-0.0285   0.9530+/-0.0252  +0.0050  2.965e-14  ***
#   mrr        0.1639+/-0.0852   0.1633+/-0.0873  -0.0006          1  ns
#   r@5        0.2457+/-0.1193   0.2481+/-0.1282  +0.0024     0.1388  ns
#   r@10       0.3655+/-0.1559   0.3630+/-0.1595  -0.0025          1  ns
#   r@20       0.4601+/-0.1741   0.4660+/-0.1765  +0.0059     0.1234  ns
#
# --- Bootstrap 95% CI ---
#
#   AUC:
#     HMDB+CTD   PROFANCY             0.8120 [0.8027,0.8205]  n=310
#     MarkerDB   PROFANCY             0.8538 [0.8173,0.8855]  n=25
#     SMPDB      PROFANCY             0.9559 [0.9525,0.9594]  n=181
#     HMDB+CTD   MetaboRank-lite-PRO  0.8067 [0.7968,0.8152]  n=310
#     MarkerDB   MetaboRank-lite-PRO  0.8516 [0.8160,0.8832]  n=25
#     SMPDB      MetaboRank-lite-PRO  0.9530 [0.9494,0.9567]  n=181
#     HMDB+CTD   CTQW-PRO             0.7740 [0.7629,0.7841]  n=310
#     MarkerDB   CTQW-PRO             0.8254 [0.7873,0.8634]  n=25
#     SMPDB      CTQW-PRO             0.9517 [0.9470,0.9567]  n=181
#     HMDB+CTD   NH γ=16.0            0.7883 [0.7774,0.7978]  n=310
#     MarkerDB   NH γ=16.0            0.8324 [0.7946,0.8702]  n=25
#     SMPDB      NH γ=16.0            0.9533 [0.9485,0.9582]  n=181
#
#   MRR:
#     HMDB+CTD   PROFANCY             0.0101 [0.0089,0.0113]  n=310
#     MarkerDB   PROFANCY             0.0159 [0.0121,0.0201]  n=25
#     SMPDB      PROFANCY             0.0580 [0.0520,0.0650]  n=181
#     HMDB+CTD   MetaboRank-lite-PRO  0.0198 [0.0160,0.0239]  n=310
#     MarkerDB   MetaboRank-lite-PRO  0.0354 [0.0231,0.0501]  n=25
#     SMPDB      MetaboRank-lite-PRO  0.1633 [0.1520,0.1753]  n=181
#     HMDB+CTD   CTQW-PRO             0.0270 [0.0212,0.0332]  n=310
#     MarkerDB   CTQW-PRO             0.0537 [0.0341,0.0776]  n=25
#     SMPDB      CTQW-PRO             0.2040 [0.1866,0.2224]  n=181
#     HMDB+CTD   NH γ=16.0            0.0295 [0.0235,0.0360]  n=310
#     MarkerDB   NH γ=16.0            0.0569 [0.0377,0.0806]  n=25
#     SMPDB      NH γ=16.0            0.2369 [0.2173,0.2579]  n=181
#
#   R@20:
#     HMDB+CTD   PROFANCY             0.0396 [0.0302,0.0490]  n=310
#     MarkerDB   PROFANCY             0.0795 [0.0479,0.1134]  n=25
#     SMPDB      PROFANCY             0.4078 [0.3843,0.4320]  n=181
#     HMDB+CTD   MetaboRank-lite-PRO  0.0708 [0.0571,0.0842]  n=310
#     MarkerDB   MetaboRank-lite-PRO  0.1432 [0.0995,0.1934]  n=25
#     SMPDB      MetaboRank-lite-PRO  0.4660 [0.4406,0.4898]  n=181
#     HMDB+CTD   CTQW-PRO             0.0818 [0.0669,0.0970]  n=310
#     MarkerDB   CTQW-PRO             0.1829 [0.1196,0.2438]  n=25
#     SMPDB      CTQW-PRO             0.5675 [0.5466,0.5883]  n=181
#     HMDB+CTD   NH γ=16.0            0.0916 [0.0768,0.1074]  n=310
#     MarkerDB   NH γ=16.0            0.1988 [0.1415,0.2575]  n=25
#     SMPDB      NH γ=16.0            0.6157 [0.5946,0.6367]  n=181
#
# --- Win counts ---
#   Pair                         Dataset    Metric  A wins  B wins   tie     n
#   --------------------------------------------------------------------
#   CTQW vs RWR                  HMDB+CTD   auc         50     260     0   310
#   CTQW vs RWR                  MarkerDB   auc          4      21     0    25
#   CTQW vs RWR                  SMPDB      auc         48     133     0   181
#   CTQW vs RWR                  HMDB+CTD   mrr        177     133     0   310
#   CTQW vs RWR                  MarkerDB   mrr         22       3     0    25
#   CTQW vs RWR                  SMPDB      mrr        181       0     0   181
#   CTQW vs MetaboRank-lite      HMDB+CTD   auc         77     233     0   310
#   CTQW vs MetaboRank-lite      MarkerDB   auc          5      20     0    25
#   CTQW vs MetaboRank-lite      SMPDB      auc         55     126     0   181
#   CTQW vs MetaboRank-lite      HMDB+CTD   mrr        147     163     0   310
#   CTQW vs MetaboRank-lite      MarkerDB   mrr         14      11     0    25
#   CTQW vs MetaboRank-lite      SMPDB      mrr        111      70     0   181
#   CTQW-PRO vs PROFANCY         HMDB+CTD   auc         62     248     0   310
#   CTQW-PRO vs PROFANCY         MarkerDB   auc          8      17     0    25
#   CTQW-PRO vs PROFANCY         SMPDB      auc         90      91     0   181
#   CTQW-PRO vs PROFANCY         HMDB+CTD   mrr        192     118     0   310
#   CTQW-PRO vs PROFANCY         MarkerDB   mrr         22       3     0    25
#   CTQW-PRO vs PROFANCY         SMPDB      mrr        181       0     0   181
#   CTQW-PRO vs MetaboRank-lite-PRO HMDB+CTD   auc         72     238     0   310
#   CTQW-PRO vs MetaboRank-lite-PRO MarkerDB   auc          5      20     0    25
#   CTQW-PRO vs MetaboRank-lite-PRO SMPDB      auc        102      79     0   181
#   CTQW-PRO vs MetaboRank-lite-PRO HMDB+CTD   mrr        159     151     0   310
#   CTQW-PRO vs MetaboRank-lite-PRO MarkerDB   mrr         16       9     0    25
#   CTQW-PRO vs MetaboRank-lite-PRO SMPDB      mrr        109      72     0   181
#   NH γ=16.0 vs CTQW-PRO        HMDB+CTD   auc        249      61     0   310
#   NH γ=16.0 vs CTQW-PRO        MarkerDB   auc         21       4     0    25
#   NH γ=16.0 vs CTQW-PRO        SMPDB      auc        124      53     4   181
#   NH γ=16.0 vs CTQW-PRO        HMDB+CTD   mrr        268      42     0   310
#   NH γ=16.0 vs CTQW-PRO        MarkerDB   mrr         24       1     0    25
#   NH γ=16.0 vs CTQW-PRO        SMPDB      mrr        177       4     0   181

# %%
# !python /content/project/experiments/02_ablation_graph_kegg.py
# Out:
# Building graphs...
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   G_pro: 3129 → clean: 3101 nodes
# Building eval sets...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:25<00:00, 1878.68it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
# Eigendecomposition...
#   eigh(3101×3101)...
#   Done in 6.2s
#
# Running ablation...
# PROF_o/HMDB+CTD: 100% 310/310 [03:31<00:00,  1.46it/s]
# CTQW_o/HMDB+CTD: 100% 310/310 [01:42<00:00,  3.02it/s]
# PROF_c/HMDB+CTD: 100% 310/310 [03:32<00:00,  1.46it/s]
# CTQW_c/HMDB+CTD: 100% 310/310 [01:40<00:00,  3.07it/s]
#   HMDB+CTD: 10.5 min
# PROF_o/MarkerDB: 100% 25/25 [00:24<00:00,  1.04it/s]
# CTQW_o/MarkerDB: 100% 25/25 [00:11<00:00,  2.11it/s]
# PROF_c/MarkerDB: 100% 25/25 [00:24<00:00,  1.01it/s]
# CTQW_c/MarkerDB: 100% 25/25 [00:12<00:00,  2.07it/s]
#   MarkerDB: 1.2 min
# PROF_o/SMPDB: 100% 181/181 [01:55<00:00,  1.57it/s]
# CTQW_o/SMPDB: 100% 181/181 [00:56<00:00,  3.18it/s]
# PROF_c/SMPDB: 100% 181/181 [01:59<00:00,  1.52it/s]
# CTQW_c/SMPDB: 100% 181/181 [00:57<00:00,  3.15it/s]
#   SMPDB: 5.8 min
#
# ========================================================================
# ABLATION: Original vs Clean G_pro_kegg
#
# === HMDB+CTD ===
# Method                   AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# ----------------------------------------------------------------------
# PROFANCY                   0.8120     0.0101     0.8145     0.0229  +0.0128
# CTQW-PRO                   0.7740     0.0270     0.7949     0.0285  +0.0016
#
# === MarkerDB ===
# Method                   AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# ----------------------------------------------------------------------
# PROFANCY                   0.8538     0.0159     0.8590     0.0407  +0.0248
# CTQW-PRO                   0.8254     0.0537     0.8403     0.0564  +0.0027
#
# === SMPDB ===
# Method                   AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# ----------------------------------------------------------------------
# PROFANCY                   0.9559     0.0580     0.9538     0.2257  +0.1678
# CTQW-PRO                   0.9517     0.2040     0.9499     0.1906  -0.0134
#
# ========================================================================
# WILCOXON: gốc vs đã loại currency metabolite (ghép cặp theo bệnh)
#
# --- HMDB+CTD (n=310) ---
#   Metric      PROFANCY_orig   PROFANCY_clean    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.8145+/-0.0885  +0.0024      0.176  ns
#   mrr        0.0101+/-0.0102   0.0229+/-0.0379  +0.0128  5.968e-50  ***
#   r@5        0.0011+/-0.0104   0.0255+/-0.0678  +0.0244  3.892e-14  ***
#   r@10       0.0134+/-0.0393   0.0443+/-0.0882  +0.0308  9.041e-18  ***
#   r@20       0.0396+/-0.0852   0.0734+/-0.1236  +0.0338  5.962e-18  ***
#
# --- HMDB+CTD (n=310) ---
#   Metric      CTQW-PRO_orig   CTQW-PRO_clean    Delta     p_bonf  Sig
#   auc        0.7740+/-0.0932   0.7949+/-0.0906  +0.0208  9.013e-10  ***
#   mrr        0.0270+/-0.0523   0.0285+/-0.0522  +0.0016    0.01398  *
#   r@5        0.0307+/-0.0813   0.0358+/-0.0827  +0.0051    0.01447  *
#   r@10       0.0510+/-0.1053   0.0565+/-0.1137  +0.0055    0.08082  .
#   r@20       0.0818+/-0.1345   0.0871+/-0.1374  +0.0053     0.3721  ns
#
# --- MarkerDB (n=25) ---
#   Metric      PROFANCY_orig   PROFANCY_clean    Delta     p_bonf  Sig
#   auc        0.8538+/-0.0838   0.8590+/-0.0877  +0.0052      0.401  ns
#   mrr        0.0159+/-0.0107   0.0407+/-0.0401  +0.0248   5.96e-07  ***
#   r@5        0.0050+/-0.0245   0.0356+/-0.0630  +0.0306    0.03843  *
#   r@10       0.0171+/-0.0396   0.0987+/-0.0977  +0.0816    0.00146  **
#   r@20       0.0795+/-0.0853   0.1485+/-0.1034  +0.0689    0.00217  **
#
# --- MarkerDB (n=25) ---
#   Metric      CTQW-PRO_orig   CTQW-PRO_clean    Delta     p_bonf  Sig
#   auc        0.8254+/-0.0972   0.8403+/-0.0960  +0.0150    0.04034  *
#   mrr        0.0537+/-0.0567   0.0564+/-0.0552  +0.0027     0.4257  ns
#   r@5        0.0570+/-0.0728   0.0621+/-0.0743  +0.0050          1  ns
#   r@10       0.1176+/-0.1297   0.1253+/-0.1071  +0.0077     0.2517  ns
#   r@20       0.1829+/-0.1570   0.1891+/-0.1195  +0.0062          1  ns
#
# --- SMPDB (n=181) ---
#   Metric      PROFANCY_orig   PROFANCY_clean    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9538+/-0.0292  -0.0021     0.9486  ns
#   mrr        0.0580+/-0.0467   0.2257+/-0.1469  +0.1678  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.3217+/-0.1950  +0.2691  1.278e-29  ***
#   r@10       0.1413+/-0.1538   0.4405+/-0.1927  +0.2992  8.388e-29  ***
#   r@20       0.4078+/-0.1718   0.5604+/-0.1970  +0.1525  2.444e-26  ***
#
# --- SMPDB (n=181) ---
#   Metric      CTQW-PRO_orig   CTQW-PRO_clean    Delta     p_bonf  Sig
#   auc        0.9517+/-0.0340   0.9499+/-0.0298  -0.0018   0.006098  **
#   mrr        0.2040+/-0.1265   0.1906+/-0.0935  -0.0134    0.05985  .
#   r@5        0.2801+/-0.1769   0.2652+/-0.1667  -0.0149    0.09713  .
#   r@10       0.4330+/-0.1745   0.4112+/-0.1730  -0.0219     0.0376  *
#   r@20       0.5675+/-0.1497   0.5848+/-0.1478  +0.0173    0.07977  .
#
# ========================================================================
# WIN-COUNT: gốc vs đã loại currency metabolite (ghép cặp theo bệnh, theo MRR)
# ========================================================================
# [HMDB+CTD] PROFANCY   loại thắng 295 | gốc thắng  15 | hoà   0 | tổng 310 bệnh (95.2% loại thắng)
# [HMDB+CTD] CTQW-PRO   loại thắng 178 | gốc thắng 132 | hoà   0 | tổng 310 bệnh (57.4% loại thắng)
# [MarkerDB] PROFANCY   loại thắng  24 | gốc thắng   1 | hoà   0 | tổng 25 bệnh (96.0% loại thắng)
# [MarkerDB] CTQW-PRO   loại thắng  16 | gốc thắng   9 | hoà   0 | tổng 25 bệnh (64.0% loại thắng)
# [SMPDB] PROFANCY   loại thắng 181 | gốc thắng   0 | hoà   0 | tổng 181 bệnh (100.0% loại thắng)
# [SMPDB] CTQW-PRO   loại thắng  82 | gốc thắng  99 | hoà   0 | tổng 181 bệnh (45.3% loại thắng)

# %%
# !python /content/project/experiments/05_supplementary_kegg.py
# Out:
# ── Supplementary S1 (KEGG): γ grid search ──
#   CSV not found — running experiment first...
# Setup pipeline (KEGG)...
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:25<00:00, 1883.86it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   HMDB+CTD: 310, SMPDB: 181
# CTQW/HMDB+CTD: 100% 310/310 [01:43<00:00,  2.99it/s]
# CTQW/SMPDB: 100% 181/181 [00:57<00:00,  3.14it/s]
#   γ=7... 69.1s
# NH(γ=7)/HMDB+CTD: 100% 310/310 [01:43<00:00,  3.00it/s]
# NH(γ=7)/SMPDB: 100% 181/181 [00:56<00:00,  3.18it/s]
#   γ=11... 69.2s
# NH(γ=11)/HMDB+CTD: 100% 310/310 [01:43<00:00,  3.00it/s]
# NH(γ=11)/SMPDB: 100% 181/181 [00:57<00:00,  3.16it/s]
#   γ=16... 69.2s
# NH(γ=16)/HMDB+CTD: 100% 310/310 [01:42<00:00,  3.02it/s]
# NH(γ=16)/SMPDB: 100% 181/181 [00:57<00:00,  3.13it/s]
#   γ=22... 69.4s
# NH(γ=22)/HMDB+CTD: 100% 310/310 [01:43<00:00,  2.99it/s]
# NH(γ=22)/SMPDB: 100% 181/181 [00:57<00:00,  3.17it/s]
#   γ=29... 69.4s
# NH(γ=29)/HMDB+CTD: 100% 310/310 [01:42<00:00,  3.03it/s]
# NH(γ=29)/SMPDB: 100% 181/181 [00:58<00:00,  3.12it/s]
#   γ=36... 68.1s
# NH(γ=36)/HMDB+CTD: 100% 310/310 [01:43<00:00,  3.01it/s]
# NH(γ=36)/SMPDB: 100% 181/181 [00:57<00:00,  3.15it/s]
#   γ=44... 68.8s
# NH(γ=44)/HMDB+CTD: 100% 310/310 [01:42<00:00,  3.01it/s]
# NH(γ=44)/SMPDB: 100% 181/181 [00:57<00:00,  3.15it/s]
#   γ=58... 69.5s
# NH(γ=58)/HMDB+CTD: 100% 310/310 [01:44<00:00,  2.95it/s]
# NH(γ=58)/SMPDB: 100% 181/181 [00:58<00:00,  3.09it/s]
#   γ=109... 69.2s
# NH(γ=109)/HMDB+CTD: 100% 310/310 [01:45<00:00,  2.94it/s]
# NH(γ=109)/SMPDB: 100% 181/181 [00:59<00:00,  3.07it/s]
#   γ=254... 69.7s
# NH(γ=254)/HMDB+CTD: 100% 310/310 [01:45<00:00,  2.94it/s]
# NH(γ=254)/SMPDB: 100% 181/181 [00:58<00:00,  3.12it/s]
#
#   [HMDB+CTD]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.0270   (baseline, γ→∞)
#        7     0.0288
#       11     0.0291
#       16     0.0295  ← paper (γ=k̄)
#       22     0.0296
#       29     0.0297
#       36     0.0297
#       44     0.0295
#       58     0.0296
#      109     0.0294
#      254     0.0292
#
#   [SMPDB]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.2040   (baseline, γ→∞)
#        7     0.2255
#       11     0.2326
#       16     0.2369  ← paper (γ=k̄)
#       22     0.2381
#       29     0.2395
#       36     0.2379
#       44     0.2359
#       58     0.2319
#      109     0.2252
#      254     0.2136
#
# ── Supplementary S2 (KEGG): t grid search ──
#   CSV not found — running experiment first...
# Setup pipeline (KEGG)...
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:25<00:00, 1878.97it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   HMDB+CTD: 310, SMPDB: 181
# CTQW-PRO(t=0.05)/HMDB+CTD: 100% 310/310 [01:43<00:00,  3.00it/s]
# CTQW-PRO(t=0.1)/HMDB+CTD: 100% 310/310 [01:45<00:00,  2.95it/s]
# CTQW-PRO(t=0.2)/HMDB+CTD: 100% 310/310 [01:45<00:00,  2.94it/s]
# CTQW-PRO(t=0.5)/HMDB+CTD: 100% 310/310 [01:47<00:00,  2.89it/s]
# CTQW-PRO(t=0.8)/HMDB+CTD: 100% 310/310 [01:44<00:00,  2.96it/s]
#
#   [CTQW-PRO, HMDB+CTD]       t        MRR
#   ------------------------
#     0.05     0.0181
#      0.1     0.0270  ← selected
#      0.2     0.0254
#      0.5     0.0210
#      0.8     0.0160

# %%
# !python /content/project/experiments/06_compare_degree_bias_method_kegg.py
# Out:
# ==============================================================================
# SETUP (KEGG)
# ==============================================================================
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:26<00:00, 1825.13it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   N = 3050, N_PRO = 3129
#   HMDB+CTD: 310 benh | SMPDB: 181 benh
#
# ==============================================================================
# PHAN A: chan doan coreness (KEGG)
# ==============================================================================
#   compute_coreness: 0.11s
#   28/29 currency metabolite trong G_pro
#   coreness toan mang: 2..26, TB 8.16
#
#   Nhom                         n   degree TB  coreness TB   (d-k) TB   k/d TB
#   Currency metabolite         28       403.4         23.5      379.9    0.217
#   Metabolite thuong         3022        10.7          7.7        3.0    0.882
#   Pathway node (ao)           79        73.5         20.5       53.1    0.350
#
#   Spearman(degree, coreness) tren node metabolite: rho = 0.9745 (p=0)
#
#   Trong so trung binh moi bien the gan cho tung nhom:
#   bien the         currency    thuong     ti le
#   core              23.5000    7.6916     3.06x   UU AI currency
#   diff               0.0204    0.6554     0.03x   PHAT currency
#   ratio              0.2168    0.8815     0.25x   PHAT currency
#
# ==============================================================================
# XAY DUNG PHUONG PHAP (KEGG)
# ==============================================================================
#   Dung NH-CTQW-PRO (gamma=16.0)... 69.8s
#   Thu tu bao cao: PROFANCY | DADA-EC | NetCore-core | NetCore-diff | NetCore-ratio | MetaboRank-lite-PRO | CTQW-PRO | NH-CTQW-PRO
#
# ==============================================================================
# PHAN B: danh gia LOO (KEGG)
# ==============================================================================
# PROFANCY/HMDB+CTD: 100% 310/310 [03:34<00:00,  1.45it/s]
#   HMDB+CTD | PROFANCY            : 3.6 min
# DADA-EC/HMDB+CTD: 100% 310/310 [03:28<00:00,  1.49it/s]
#   HMDB+CTD | DADA-EC             : 3.5 min
# NetCore-core/HMDB+CTD: 100% 310/310 [03:29<00:00,  1.48it/s]
#   HMDB+CTD | NetCore-core        : 3.5 min
# NetCore-diff/HMDB+CTD: 100% 310/310 [04:09<00:00,  1.24it/s]
#   HMDB+CTD | NetCore-diff        : 4.2 min
# NetCore-ratio/HMDB+CTD: 100% 310/310 [03:42<00:00,  1.39it/s]
#   HMDB+CTD | NetCore-ratio       : 3.7 min
# MetaboRank-lite-PRO/HMDB+CTD: 100% 310/310 [03:32<00:00,  1.46it/s]
#   HMDB+CTD | MetaboRank-lite-PRO : 3.5 min
# CTQW-PRO/HMDB+CTD: 100% 310/310 [01:42<00:00,  3.01it/s]
#   HMDB+CTD | CTQW-PRO            : 1.7 min
# NH-CTQW-PRO/HMDB+CTD: 100% 310/310 [01:41<00:00,  3.06it/s]
#   HMDB+CTD | NH-CTQW-PRO         : 1.7 min
#
# === HMDB+CTD (n=310) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8120   0.0101  0.0011  0.0134  0.0396
# DADA-EC                  0.7654   0.0106  0.0073  0.0174  0.0431 ◄
# NetCore-core             0.7986   0.0093  0.0007  0.0113  0.0373
# NetCore-diff             0.7524   0.0134  0.0108  0.0204  0.0470 ◄
# NetCore-ratio            0.7962   0.0202  0.0237  0.0401  0.0706 ◄
# MetaboRank-lite-PRO      0.8067   0.0198  0.0222  0.0371  0.0708 ◄
# CTQW-PRO                 0.7740   0.0270  0.0307  0.0510  0.0818 ◄
# NH-CTQW-PRO              0.7883   0.0295  0.0353  0.0595  0.0916 ◄
# PROFANCY/SMPDB: 100% 181/181 [01:55<00:00,  1.56it/s]
#   SMPDB | PROFANCY            : 1.9 min
# DADA-EC/SMPDB: 100% 181/181 [01:50<00:00,  1.64it/s]
#   SMPDB | DADA-EC             : 1.8 min
# NetCore-core/SMPDB: 100% 181/181 [01:52<00:00,  1.60it/s]
#   SMPDB | NetCore-core        : 1.9 min
# NetCore-diff/SMPDB: 100% 181/181 [02:14<00:00,  1.34it/s]
#   SMPDB | NetCore-diff        : 2.2 min
# NetCore-ratio/SMPDB: 100% 181/181 [01:54<00:00,  1.58it/s]
#   SMPDB | NetCore-ratio       : 1.9 min
# MetaboRank-lite-PRO/SMPDB: 100% 181/181 [01:53<00:00,  1.59it/s]
#   SMPDB | MetaboRank-lite-PRO : 1.9 min
# CTQW-PRO/SMPDB: 100% 181/181 [00:56<00:00,  3.18it/s]
#   SMPDB | CTQW-PRO            : 0.9 min
# NH-CTQW-PRO/SMPDB: 100% 181/181 [00:57<00:00,  3.14it/s]
#   SMPDB | NH-CTQW-PRO         : 1.0 min
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9559   0.0580  0.0526  0.1413  0.4078
# DADA-EC                  0.9226   0.0655  0.0916  0.1822  0.2741 ◄
# NetCore-core             0.9556   0.0497  0.0434  0.1063  0.3215
# NetCore-diff             0.9208   0.0981  0.1433  0.2247  0.3036 ◄
# NetCore-ratio            0.9513   0.1760  0.2457  0.3533  0.4626 ◄
# MetaboRank-lite-PRO      0.9530   0.1633  0.2481  0.3630  0.4660 ◄
# CTQW-PRO                 0.9517   0.2040  0.2801  0.4330  0.5675 ◄
# NH-CTQW-PRO              0.9533   0.2369  0.3255  0.4946  0.6157 ◄
#
# ==============================================================================
# PHAN D: kiem dinh thong ke (KEGG)
# ==============================================================================
#
# ##############################################################################
# # HMDB+CTD: tung phuong phap vs PROFANCY
# ##############################################################################
#
# --- HMDB+CTD: DADA-EC vs PROFANCY (n=310) ---
#   Metric           PROFANCY          DADA-EC    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7654+/-0.1017  -0.0466  1.205e-42  ***
#   mrr        0.0101+/-0.0102   0.0106+/-0.0170  +0.0005    0.07948  .
#   r@5        0.0011+/-0.0104   0.0073+/-0.0378  +0.0062    0.01396  *
#   r@10       0.0134+/-0.0393   0.0174+/-0.0594  +0.0040     0.4683  ns
#   r@20       0.0396+/-0.0852   0.0431+/-0.0899  +0.0036     0.9009  ns
#
# --- HMDB+CTD: NetCore-core vs PROFANCY (n=310) ---
#   Metric           PROFANCY     NetCore-core    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7986+/-0.0808  -0.0134  2.585e-16  ***
#   mrr        0.0101+/-0.0102   0.0093+/-0.0091  -0.0007    0.00788  **
#   r@5        0.0011+/-0.0104   0.0007+/-0.0083  -0.0004          1  ns
#   r@10       0.0134+/-0.0393   0.0113+/-0.0351  -0.0021     0.6356  ns
#   r@20       0.0396+/-0.0852   0.0373+/-0.0778  -0.0023          1  ns
#
# --- HMDB+CTD: NetCore-diff vs PROFANCY (n=310) ---
#   Metric           PROFANCY     NetCore-diff    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7524+/-0.1075  -0.0597  2.439e-41  ***
#   mrr        0.0101+/-0.0102   0.0134+/-0.0245  +0.0033          1  ns
#   r@5        0.0011+/-0.0104   0.0108+/-0.0427  +0.0097  4.009e-05  ***
#   r@10       0.0134+/-0.0393   0.0204+/-0.0546  +0.0070    0.03978  *
#   r@20       0.0396+/-0.0852   0.0470+/-0.0931  +0.0074     0.1844  ns
#
# --- HMDB+CTD: NetCore-ratio vs PROFANCY (n=310) ---
#   Metric           PROFANCY    NetCore-ratio    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7962+/-0.0944  -0.0158  7.876e-15  ***
#   mrr        0.0101+/-0.0102   0.0202+/-0.0339  +0.0102  4.009e-11  ***
#   r@5        0.0011+/-0.0104   0.0237+/-0.0585  +0.0226  2.268e-12  ***
#   r@10       0.0134+/-0.0393   0.0401+/-0.0828  +0.0267  5.798e-12  ***
#   r@20       0.0396+/-0.0852   0.0706+/-0.1139  +0.0310  9.439e-12  ***
#
# --- HMDB+CTD: MetaboRank-lite-PRO vs PROFANCY (n=310) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.8067+/-0.0864  -0.0053  2.901e-14  ***
#   mrr        0.0101+/-0.0102   0.0198+/-0.0344  +0.0097  2.092e-18  ***
#   r@5        0.0011+/-0.0104   0.0222+/-0.0561  +0.0211  1.275e-12  ***
#   r@10       0.0134+/-0.0393   0.0371+/-0.0796  +0.0236  3.671e-10  ***
#   r@20       0.0396+/-0.0852   0.0708+/-0.1165  +0.0312  2.334e-12  ***
#
# --- HMDB+CTD: CTQW-PRO vs PROFANCY (n=310) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7740+/-0.0932  -0.0380  7.522e-27  ***
#   mrr        0.0101+/-0.0102   0.0270+/-0.0523  +0.0169  1.739e-12  ***
#   r@5        0.0011+/-0.0104   0.0307+/-0.0813  +0.0296  3.773e-12  ***
#   r@10       0.0134+/-0.0393   0.0510+/-0.1053  +0.0376  5.355e-13  ***
#   r@20       0.0396+/-0.0852   0.0818+/-0.1345  +0.0422  3.014e-14  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs PROFANCY (n=310) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7883+/-0.0889  -0.0237  3.391e-16  ***
#   mrr        0.0101+/-0.0102   0.0295+/-0.0540  +0.0194   4.22e-19  ***
#   r@5        0.0011+/-0.0104   0.0353+/-0.0814  +0.0342  8.453e-15  ***
#   r@10       0.0134+/-0.0393   0.0595+/-0.1176  +0.0461   1.72e-15  ***
#   r@20       0.0396+/-0.0852   0.0916+/-0.1366  +0.0521  4.682e-18  ***
#
# ##############################################################################
# # HMDB+CTD: CTQW-PRO / NH-CTQW-PRO vs TUNG baseline
# ##############################################################################
#
# --- HMDB+CTD: CTQW-PRO vs PROFANCY (n=310) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7740+/-0.0932  -0.0380  7.522e-27  ***
#   mrr        0.0101+/-0.0102   0.0270+/-0.0523  +0.0169  1.739e-12  ***
#   r@5        0.0011+/-0.0104   0.0307+/-0.0813  +0.0296  3.773e-12  ***
#   r@10       0.0134+/-0.0393   0.0510+/-0.1053  +0.0376  5.355e-13  ***
#   r@20       0.0396+/-0.0852   0.0818+/-0.1345  +0.0422  3.014e-14  ***
#
# --- HMDB+CTD: CTQW-PRO vs DADA-EC (n=310) ---
#   Metric            DADA-EC         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7654+/-0.1017   0.7740+/-0.0932  +0.0086    0.05992  .
#   mrr        0.0106+/-0.0170   0.0270+/-0.0523  +0.0164  5.949e-19  ***
#   r@5        0.0073+/-0.0378   0.0307+/-0.0813  +0.0234   1.31e-08  ***
#   r@10       0.0174+/-0.0594   0.0510+/-0.1053  +0.0336  1.096e-09  ***
#   r@20       0.0431+/-0.0899   0.0818+/-0.1345  +0.0386  8.667e-10  ***
#
# --- HMDB+CTD: CTQW-PRO vs NetCore-core (n=310) ---
#   Metric       NetCore-core         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7986+/-0.0808   0.7740+/-0.0932  -0.0245  1.618e-13  ***
#   mrr        0.0093+/-0.0091   0.0270+/-0.0523  +0.0176  1.226e-18  ***
#   r@5        0.0007+/-0.0083   0.0307+/-0.0813  +0.0300  3.774e-12  ***
#   r@10       0.0113+/-0.0351   0.0510+/-0.1053  +0.0397  4.053e-13  ***
#   r@20       0.0373+/-0.0778   0.0818+/-0.1345  +0.0445  3.042e-14  ***
#
# --- HMDB+CTD: CTQW-PRO vs NetCore-diff (n=310) ---
#   Metric       NetCore-diff         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7524+/-0.1075   0.7740+/-0.0932  +0.0217  2.747e-07  ***
#   mrr        0.0134+/-0.0245   0.0270+/-0.0523  +0.0136  3.928e-12  ***
#   r@5        0.0108+/-0.0427   0.0307+/-0.0813  +0.0200  2.522e-06  ***
#   r@10       0.0204+/-0.0546   0.0510+/-0.1053  +0.0306  9.365e-08  ***
#   r@20       0.0470+/-0.0931   0.0818+/-0.1345  +0.0348  4.862e-07  ***
#
# --- HMDB+CTD: CTQW-PRO vs NetCore-ratio (n=310) ---
#   Metric      NetCore-ratio         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7962+/-0.0944   0.7740+/-0.0932  -0.0222  5.034e-10  ***
#   mrr        0.0202+/-0.0339   0.0270+/-0.0523  +0.0067      0.488  ns
#   r@5        0.0237+/-0.0585   0.0307+/-0.0813  +0.0071          1  ns
#   r@10       0.0401+/-0.0828   0.0510+/-0.1053  +0.0109     0.3356  ns
#   r@20       0.0706+/-0.1139   0.0818+/-0.1345  +0.0112     0.4207  ns
#
# --- HMDB+CTD: CTQW-PRO vs MetaboRank-lite-PRO (n=310) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8067+/-0.0864   0.7740+/-0.0932  -0.0326  1.391e-21  ***
#   mrr        0.0198+/-0.0344   0.0270+/-0.0523  +0.0072     0.4014  ns
#   r@5        0.0222+/-0.0561   0.0307+/-0.0813  +0.0085      0.535  ns
#   r@10       0.0371+/-0.0796   0.0510+/-0.1053  +0.0139    0.03554  *
#   r@20       0.0708+/-0.1165   0.0818+/-0.1345  +0.0110     0.2854  ns
#
# --- HMDB+CTD: NH-CTQW-PRO vs PROFANCY (n=310) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8120+/-0.0827   0.7883+/-0.0889  -0.0237  3.391e-16  ***
#   mrr        0.0101+/-0.0102   0.0295+/-0.0540  +0.0194   4.22e-19  ***
#   r@5        0.0011+/-0.0104   0.0353+/-0.0814  +0.0342  8.453e-15  ***
#   r@10       0.0134+/-0.0393   0.0595+/-0.1176  +0.0461   1.72e-15  ***
#   r@20       0.0396+/-0.0852   0.0916+/-0.1366  +0.0521  4.682e-18  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs DADA-EC (n=310) ---
#   Metric            DADA-EC      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7654+/-0.1017   0.7883+/-0.0889  +0.0229  8.401e-10  ***
#   mrr        0.0106+/-0.0170   0.0295+/-0.0540  +0.0189  2.382e-24  ***
#   r@5        0.0073+/-0.0378   0.0353+/-0.0814  +0.0280  4.119e-11  ***
#   r@10       0.0174+/-0.0594   0.0595+/-0.1176  +0.0421  1.475e-12  ***
#   r@20       0.0431+/-0.0899   0.0916+/-0.1366  +0.0485  5.941e-14  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs NetCore-core (n=310) ---
#   Metric       NetCore-core      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7986+/-0.0808   0.7883+/-0.0889  -0.0103  0.0004689  ***
#   mrr        0.0093+/-0.0091   0.0295+/-0.0540  +0.0201  4.483e-24  ***
#   r@5        0.0007+/-0.0083   0.0353+/-0.0814  +0.0346  8.455e-15  ***
#   r@10       0.0113+/-0.0351   0.0595+/-0.1176  +0.0482  2.511e-15  ***
#   r@20       0.0373+/-0.0778   0.0916+/-0.1366  +0.0544  5.835e-18  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs NetCore-diff (n=310) ---
#   Metric       NetCore-diff      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7524+/-0.1075   0.7883+/-0.0889  +0.0359  6.298e-18  ***
#   mrr        0.0134+/-0.0245   0.0295+/-0.0540  +0.0161   5.32e-18  ***
#   r@5        0.0108+/-0.0427   0.0353+/-0.0814  +0.0245  5.824e-09  ***
#   r@10       0.0204+/-0.0546   0.0595+/-0.1176  +0.0391  1.932e-11  ***
#   r@20       0.0470+/-0.0931   0.0916+/-0.1366  +0.0446   8.16e-12  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs NetCore-ratio (n=310) ---
#   Metric      NetCore-ratio      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7962+/-0.0944   0.7883+/-0.0889  -0.0079    0.04863  *
#   mrr        0.0202+/-0.0339   0.0295+/-0.0540  +0.0092  5.196e-05  ***
#   r@5        0.0237+/-0.0585   0.0353+/-0.0814  +0.0116    0.03989  *
#   r@10       0.0401+/-0.0828   0.0595+/-0.1176  +0.0194   0.001453  **
#   r@20       0.0706+/-0.1139   0.0916+/-0.1366  +0.0210  0.0005393  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs MetaboRank-lite-PRO (n=310) ---
#   Metric   MetaboRank-lite-PRO      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8067+/-0.0864   0.7883+/-0.0889  -0.0184  1.221e-10  ***
#   mrr        0.0198+/-0.0344   0.0295+/-0.0540  +0.0097  9.017e-05  ***
#   r@5        0.0222+/-0.0561   0.0353+/-0.0814  +0.0131    0.01198  *
#   r@10       0.0371+/-0.0796   0.0595+/-0.1176  +0.0225  3.915e-05  ***
#   r@20       0.0708+/-0.1165   0.0916+/-0.1366  +0.0208  8.062e-05  ***
#
# ##############################################################################
# # SMPDB: tung phuong phap vs PROFANCY
# ##############################################################################
#
# --- SMPDB: DADA-EC vs PROFANCY (n=181) ---
#   Metric           PROFANCY          DADA-EC    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9226+/-0.0377  -0.0333  1.051e-28  ***
#   mrr        0.0580+/-0.0467   0.0655+/-0.0533  +0.0076    0.07243  .
#   r@5        0.0526+/-0.1008   0.0916+/-0.0953  +0.0389  8.023e-05  ***
#   r@10       0.1413+/-0.1538   0.1822+/-0.1332  +0.0409    0.00294  **
#   r@20       0.4078+/-0.1718   0.2741+/-0.1579  -0.1337  2.135e-14  ***
#
# --- SMPDB: NetCore-core vs PROFANCY (n=181) ---
#   Metric           PROFANCY     NetCore-core    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9556+/-0.0253  -0.0003          1  ns
#   mrr        0.0580+/-0.0467   0.0497+/-0.0389  -0.0083  3.338e-29  ***
#   r@5        0.0526+/-0.1008   0.0434+/-0.0801  -0.0092  0.0005284  ***
#   r@10       0.1413+/-0.1538   0.1063+/-0.1185  -0.0350  4.954e-11  ***
#   r@20       0.4078+/-0.1718   0.3215+/-0.1708  -0.0863  2.428e-19  ***
#
# --- SMPDB: NetCore-diff vs PROFANCY (n=181) ---
#   Metric           PROFANCY     NetCore-diff    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9208+/-0.0393  -0.0351  1.909e-24  ***
#   mrr        0.0580+/-0.0467   0.0981+/-0.0759  +0.0401    4.4e-11  ***
#   r@5        0.0526+/-0.1008   0.1433+/-0.1101  +0.0907  9.438e-15  ***
#   r@10       0.1413+/-0.1538   0.2247+/-0.1535  +0.0834  1.079e-06  ***
#   r@20       0.4078+/-0.1718   0.3036+/-0.1704  -0.1042  1.502e-07  ***
#
# --- SMPDB: NetCore-ratio vs PROFANCY (n=181) ---
#   Metric           PROFANCY    NetCore-ratio    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9513+/-0.0267  -0.0046  0.0006169  ***
#   mrr        0.0580+/-0.0467   0.1760+/-0.1024  +0.1181  1.529e-29  ***
#   r@5        0.0526+/-0.1008   0.2457+/-0.1351  +0.1931  2.207e-24  ***
#   r@10       0.1413+/-0.1538   0.3533+/-0.1731  +0.2120  1.073e-23  ***
#   r@20       0.4078+/-0.1718   0.4626+/-0.1912  +0.0547  0.0003249  ***
#
# --- SMPDB: MetaboRank-lite-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9530+/-0.0252  -0.0029  1.054e-13  ***
#   mrr        0.0580+/-0.0467   0.1633+/-0.0873  +0.1053  1.386e-29  ***
#   r@5        0.0526+/-0.1008   0.2481+/-0.1282  +0.1954  1.809e-25  ***
#   r@10       0.1413+/-0.1538   0.3630+/-0.1595  +0.2217  1.597e-24  ***
#   r@20       0.4078+/-0.1718   0.4660+/-0.1765  +0.0582  0.0007518  ***
#
# --- SMPDB: CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9517+/-0.0340  -0.0042     0.8002  ns
#   mrr        0.0580+/-0.0467   0.2040+/-0.1265  +0.1461  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.2801+/-0.1769  +0.2275  8.103e-28  ***
#   r@10       0.1413+/-0.1538   0.4330+/-0.1745  +0.2917  1.226e-28  ***
#   r@20       0.4078+/-0.1718   0.5675+/-0.1497  +0.1597  9.114e-27  ***
#
# --- SMPDB: NH-CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9533+/-0.0343  -0.0026          1  ns
#   mrr        0.0580+/-0.0467   0.2369+/-0.1457  +0.1789  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.3255+/-0.1993  +0.2729   4.09e-30  ***
#   r@10       0.1413+/-0.1538   0.4946+/-0.1843  +0.3533  4.878e-30  ***
#   r@20       0.4078+/-0.1718   0.6157+/-0.1439  +0.2078  2.728e-28  ***
#
# ##############################################################################
# # SMPDB: CTQW-PRO / NH-CTQW-PRO vs TUNG baseline
# ##############################################################################
#
# --- SMPDB: CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9517+/-0.0340  -0.0042     0.8002  ns
#   mrr        0.0580+/-0.0467   0.2040+/-0.1265  +0.1461  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.2801+/-0.1769  +0.2275  8.103e-28  ***
#   r@10       0.1413+/-0.1538   0.4330+/-0.1745  +0.2917  1.226e-28  ***
#   r@20       0.4078+/-0.1718   0.5675+/-0.1497  +0.1597  9.114e-27  ***
#
# --- SMPDB: CTQW-PRO vs DADA-EC (n=181) ---
#   Metric            DADA-EC         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9226+/-0.0377   0.9517+/-0.0340  +0.0291  4.156e-19  ***
#   mrr        0.0655+/-0.0533   0.2040+/-0.1265  +0.1385  4.645e-28  ***
#   r@5        0.0916+/-0.0953   0.2801+/-0.1769  +0.1885  1.476e-22  ***
#   r@10       0.1822+/-0.1332   0.4330+/-0.1745  +0.2509  8.805e-27  ***
#   r@20       0.2741+/-0.1579   0.5675+/-0.1497  +0.2933  8.842e-30  ***
#
# --- SMPDB: CTQW-PRO vs NetCore-core (n=181) ---
#   Metric       NetCore-core         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9556+/-0.0253   0.9517+/-0.0340  -0.0039     0.3856  ns
#   mrr        0.0497+/-0.0389   0.2040+/-0.1265  +0.1544  9.124e-31  ***
#   r@5        0.0434+/-0.0801   0.2801+/-0.1769  +0.2367  5.528e-28  ***
#   r@10       0.1063+/-0.1185   0.4330+/-0.1745  +0.3268  8.976e-31  ***
#   r@20       0.3215+/-0.1708   0.5675+/-0.1497  +0.2459  8.664e-30  ***
#
# --- SMPDB: CTQW-PRO vs NetCore-diff (n=181) ---
#   Metric       NetCore-diff         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9208+/-0.0393   0.9517+/-0.0340  +0.0309  2.881e-17  ***
#   mrr        0.0981+/-0.0759   0.2040+/-0.1265  +0.1060  1.255e-14  ***
#   r@5        0.1433+/-0.1101   0.2801+/-0.1769  +0.1368  1.352e-13  ***
#   r@10       0.2247+/-0.1535   0.4330+/-0.1745  +0.2083  2.749e-22  ***
#   r@20       0.3036+/-0.1704   0.5675+/-0.1497  +0.2639  2.789e-27  ***
#
# --- SMPDB: CTQW-PRO vs NetCore-ratio (n=181) ---
#   Metric      NetCore-ratio         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9513+/-0.0267   0.9517+/-0.0340  +0.0004      0.499  ns
#   mrr        0.1760+/-0.1024   0.2040+/-0.1265  +0.0280    0.06561  .
#   r@5        0.2457+/-0.1351   0.2801+/-0.1769  +0.0343     0.4684  ns
#   r@10       0.3533+/-0.1731   0.4330+/-0.1745  +0.0797  5.512e-05  ***
#   r@20       0.4626+/-0.1912   0.5675+/-0.1497  +0.1049  3.781e-10  ***
#
# --- SMPDB: CTQW-PRO vs MetaboRank-lite-PRO (n=181) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9530+/-0.0252   0.9517+/-0.0340  -0.0013          1  ns
#   mrr        0.1633+/-0.0873   0.2040+/-0.1265  +0.0407   0.002131  **
#   r@5        0.2481+/-0.1282   0.2801+/-0.1769  +0.0320     0.9388  ns
#   r@10       0.3630+/-0.1595   0.4330+/-0.1745  +0.0700  7.119e-06  ***
#   r@20       0.4660+/-0.1765   0.5675+/-0.1497  +0.1015  2.474e-10  ***
#
# --- SMPDB: NH-CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9533+/-0.0343  -0.0026          1  ns
#   mrr        0.0580+/-0.0467   0.2369+/-0.1457  +0.1789  9.124e-31  ***
#   r@5        0.0526+/-0.1008   0.3255+/-0.1993  +0.2729   4.09e-30  ***
#   r@10       0.1413+/-0.1538   0.4946+/-0.1843  +0.3533  4.878e-30  ***
#   r@20       0.4078+/-0.1718   0.6157+/-0.1439  +0.2078  2.728e-28  ***
#
# --- SMPDB: NH-CTQW-PRO vs DADA-EC (n=181) ---
#   Metric            DADA-EC      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9226+/-0.0377   0.9533+/-0.0343  +0.0307  2.537e-18  ***
#   mrr        0.0655+/-0.0533   0.2369+/-0.1457  +0.1714  3.921e-30  ***
#   r@5        0.0916+/-0.0953   0.3255+/-0.1993  +0.2340  1.235e-25  ***
#   r@10       0.1822+/-0.1332   0.4946+/-0.1843  +0.3124  5.031e-28  ***
#   r@20       0.2741+/-0.1579   0.6157+/-0.1439  +0.3415  1.955e-30  ***
#
# --- SMPDB: NH-CTQW-PRO vs NetCore-core (n=181) ---
#   Metric       NetCore-core      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9556+/-0.0253   0.9533+/-0.0343  -0.0023          1  ns
#   mrr        0.0497+/-0.0389   0.2369+/-0.1457  +0.1872  9.124e-31  ***
#   r@5        0.0434+/-0.0801   0.3255+/-0.1993  +0.2821  2.788e-30  ***
#   r@10       0.1063+/-0.1185   0.4946+/-0.1843  +0.3883   9.11e-31  ***
#   r@20       0.3215+/-0.1708   0.6157+/-0.1439  +0.2941  8.743e-30  ***
#
# --- SMPDB: NH-CTQW-PRO vs NetCore-diff (n=181) ---
#   Metric       NetCore-diff      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9208+/-0.0393   0.9533+/-0.0343  +0.0325  2.631e-16  ***
#   mrr        0.0981+/-0.0759   0.2369+/-0.1457  +0.1388  5.374e-18  ***
#   r@5        0.1433+/-0.1101   0.3255+/-0.1993  +0.1822  3.849e-17  ***
#   r@10       0.2247+/-0.1535   0.4946+/-0.1843  +0.2699  9.976e-26  ***
#   r@20       0.3036+/-0.1704   0.6157+/-0.1439  +0.3121  1.066e-28  ***
#
# --- SMPDB: NH-CTQW-PRO vs NetCore-ratio (n=181) ---
#   Metric      NetCore-ratio      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9513+/-0.0267   0.9533+/-0.0343  +0.0020    0.01697  *
#   mrr        0.1760+/-0.1024   0.2369+/-0.1457  +0.0609  1.616e-07  ***
#   r@5        0.2457+/-0.1351   0.3255+/-0.1993  +0.0798  0.0002581  ***
#   r@10       0.3533+/-0.1731   0.4946+/-0.1843  +0.1412  2.199e-13  ***
#   r@20       0.4626+/-0.1912   0.6157+/-0.1439  +0.1531  2.645e-20  ***
#
# --- SMPDB: NH-CTQW-PRO vs MetaboRank-lite-PRO (n=181) ---
#   Metric   MetaboRank-lite-PRO      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9530+/-0.0252   0.9533+/-0.0343  +0.0003     0.1193  ns
#   mrr        0.1633+/-0.0873   0.2369+/-0.1457  +0.0736  5.004e-09  ***
#   r@5        0.2481+/-0.1282   0.3255+/-0.1993  +0.0775  5.203e-05  ***
#   r@10       0.3630+/-0.1595   0.4946+/-0.1843  +0.1315  3.703e-15  ***
#   r@20       0.4660+/-0.1765   0.6157+/-0.1439  +0.1497  1.678e-22  ***
#
# ==============================================================================
# PHAN E: bang tong hop (KEGG)
# ==============================================================================
#
# === HMDB+CTD ===
# Phuong phap                AUC     MRR     R@5    R@10    R@20
# --------------------------------------------------------------
# PROFANCY                0.8120  0.0101  0.0011  0.0134  0.0396
# DADA-EC                 0.7654  0.0106  0.0073  0.0174  0.0431
# NetCore-core            0.7986  0.0093  0.0007  0.0113  0.0373
# NetCore-diff            0.7524  0.0134  0.0108  0.0204  0.0470
# NetCore-ratio           0.7962  0.0202  0.0237  0.0401  0.0706
# MetaboRank-lite-PRO     0.8067  0.0198  0.0222  0.0371  0.0708
# CTQW-PRO                0.7740  0.0270  0.0307  0.0510  0.0818
# NH-CTQW-PRO             0.7883  0.0295  0.0353  0.0595  0.0916
#   -> da luu kegg_E_bang_HMDBCTD.csv
#
# === SMPDB ===
# Phuong phap                AUC     MRR     R@5    R@10    R@20
# --------------------------------------------------------------
# PROFANCY                0.9559  0.0580  0.0526  0.1413  0.4078
# DADA-EC                 0.9226  0.0655  0.0916  0.1822  0.2741
# NetCore-core            0.9556  0.0497  0.0434  0.1063  0.3215
# NetCore-diff            0.9208  0.0981  0.1433  0.2247  0.3036
# NetCore-ratio           0.9513  0.1760  0.2457  0.3533  0.4626
# MetaboRank-lite-PRO     0.9530  0.1633  0.2481  0.3630  0.4660
# CTQW-PRO                0.9517  0.2040  0.2801  0.4330  0.5675
# NH-CTQW-PRO             0.9533  0.2369  0.3255  0.4946  0.6157
#   -> da luu kegg_E_bang_SMPDB.csv
#
# ==============================================================================
# XONG
# ==============================================================================

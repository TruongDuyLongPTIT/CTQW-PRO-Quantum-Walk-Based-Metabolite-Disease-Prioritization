# %%
import shutil, os
if os.path.exists('/content/project'):
    shutil.rmtree('/content/project')
# !git clone https://github.com/TruongDuyLongPTIT/CTQW-PRO-Quantum-Walk-Based-Metabolite-Disease-Prioritization.git /content/project

# Add src vào Python path
import sys
sys.path.insert(0, '/content/project/src')

# Install dependencies
# !pip install -q scikit-learn networkx tqdm
# Out:
# Cloning into '/content/project'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 28 (delta 5), reused 28 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 45.89 KiB | 959.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
from pathlib import Path
from google.colab import drive

if not Path('/content/drive/MyDrive').exists():
    drive.mount('/content/drive')
else:
    print("Drive đã mount sẵn.")
# Out:
# Mounted at /content/drive

# %%
# !python /content/project/experiments/01_main_results.py
# Out:
# ...
# STEP 1 — Build graph
#   Parsed in 1.2s → cached
#   Graph: 2788 nodes, 22439 edges
#   G_pro: 2894 nodes (106 pathway), 31360 edges
#
# STEP 2 — Build eval sets
#   Parsing HMDB (~10-20 min)...
#   Done in 195.4s → cached
#   hmdb_to_recon: +0 IK, +331 name → 3286 total
#   CTD parsed in 11.6s
#   Parsed 1090 markers in 0.4s
#   Extracting SMPDB metabolites...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:26<00:00, 1828.20it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#   eval_set1 (HMDB+CTD): 171 diseases
#   eval_set2 (MarkerDB): 23 diseases
#   eval_set3 (SMPDB):    167 diseases
#   HMDB+CTD: 171 tên bệnh → 170 seed-set độc lập
#   MarkerDB: 23 tên bệnh → 23 seed-set độc lập
#   SMPDB: 167 tên bệnh → 43 seed-set độc lập
#
# STEP 3 — Eigendecomposition
#   eigh(2894×2894)...
#   Done in 3.4s
#   eigh(2788×2788)...
#   Done in 4.8s
#   Done.
#
# ...
# [Table 1] RWR vs CTQW on G_cc...
# RWR/HMDB+CTD: 100% 171/171 [01:36<00:00,  1.77it/s]
# ...

# %%
# !python /content/project/experiments/02_ablation_graph.py
# Out:
# Building graphs...
#   G_pro: 2894 → clean: 2864 nodes
# Building eval sets...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:27<00:00, 1746.28it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
# Eigendecomposition...
#   eigh(2864×2864)...
#   Done in 3.6s
#
# Running ablation...
# PROF_o/HMDB+CTD: 100% 171/171 [01:45<00:00,  1.61it/s]
# CTQW_o/HMDB+CTD: 100% 171/171 [00:53<00:00,  3.18it/s]
# PROF_c/HMDB+CTD: 100% 171/171 [01:47<00:00,  1.60it/s]
# CTQW_c/HMDB+CTD: 100% 171/171 [00:51<00:00,  3.30it/s]
#   HMDB+CTD: 5.3 min
# PROF_o/MarkerDB: 100% 23/23 [00:18<00:00,  1.23it/s]
# CTQW_o/MarkerDB: 100% 23/23 [00:09<00:00,  2.36it/s]
# PROF_c/MarkerDB: 100% 23/23 [00:18<00:00,  1.26it/s]
# CTQW_c/MarkerDB: 100% 23/23 [00:09<00:00,  2.47it/s]
#   MarkerDB: 0.9 min
# PROF_o/SMPDB: 100% 167/167 [01:27<00:00,  1.91it/s]
# CTQW_o/SMPDB: 100% 167/167 [00:44<00:00,  3.76it/s]
# PROF_c/SMPDB: 100% 167/167 [01:23<00:00,  2.00it/s]
# ...

# %%
# !python /content/project/experiments/04_biological_interpretability.py
# Out:
# ...
# 04 — Biological Interpretability Analysis
# ...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:27<00:00, 1760.24it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
# Building NH-CTQW-PRO (γ=22.0, t=0.1)... 52.6s
#
# ...
# DISEASE: Lesch-Nyhan Syndrome (LNS)  [LNS]
# ...
#
# Seeds (n=29) — known disease metabolites:
#     #  Name                                                         HMDB
#   ----------------------------------------------------------------------
#     1. (S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate    HMDB0000797
#     2. Adenine                                               HMDB0000034
#     3. Adenosine                                             HMDB0004402
#     4. 5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide    HMDB0001517
#     5. L-Aspartate                                           HMDB0062186
#     6. Calcium                                               HMDB0000464
# ...

# %%
# !python /content/project/experiments/05_supplementary.py
# Out:
# ── Supplementary S1: γ grid search ──
#
#   [HMDB+CTD]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.0621   (baseline, γ→∞)
#       10     0.0651
#       15     0.0651
#       22     0.0659  ← paper (γ=k̄)
#       30     0.0662
#       40     0.0662
#       50     0.0663
#       60     0.0661
#       80     0.0659
#      150     0.0656
#      349     0.0637
#
#   [SMPDB]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.1714   (baseline, γ→∞)
#       10     0.2121
#       15     0.2188
#       22     0.2246  ← paper (γ=k̄)
#       30     0.2223
#       40     0.2217
#       50     0.2263
#       60     0.2275
#       80     0.2247
#      150     0.2255
#      349     0.2252
#
# ── Supplementary S2: t grid search ──
#
#   [CTQW-PRO, HMDB+CTD]       t        MRR
#   ------------------------
#     0.05     0.0378
#      0.1     0.0621  ← selected
#      0.2     0.0437
#      0.5     0.0431
#      0.8     0.0279

# %%
# !python /content/project/experiments/06_compare_degree_bias_method.py
# Out:
# ...
# SETUP
# ...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:27<00:00, 1767.96it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#   N = 2788, N_PRO = 2894
#   HMDB+CTD: 171 benh | SMPDB: 167 benh
#
# ...
# PHAN A: coreness
# ...
#   compute_coreness: 0.15s
#   29/29 currency metabolite trong G_pro
#   Currency metabolite      n=   29  degree TB = 481.6  coreness TB = 39.2
#   Metabolite thuong        n= 2759  degree TB = 14.4  coreness TB = 11.4
#
# ...
# XAY DUNG PHUONG PHAP
# ...
#   [IN] kf* = 850 | entropy 6.8158 -> 7.6912
#   Dung NH-CTQW-PRO (gamma=22.0)... 52.1s
#   Thu tu bao cao: PROFANCY | DADA-EC | NetCore-core | NetCore-diff | NetCore-ratio | MetaboRank-LITE | AMEND-IN-LITE | CTQW-PRO | NH-CTQW-PRO
#
# ...
# PHAN B: danh gia LOO
# ...
# PROFANCY/HMDB+CTD: 100% 171/171 [01:47<00:00,  1.58it/s]
#   HMDB+CTD | PROFANCY            : 1.8 min
# DADA-EC/HMDB+CTD: 100% 171/171 [01:45<00:00,  1.63it/s]
#   HMDB+CTD | DADA-EC             : 1.8 min
# ...

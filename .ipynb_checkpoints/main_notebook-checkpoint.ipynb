# %%
import shutil, os
if os.path.exists('/content/project'):
    shutil.rmtree('/content/project')
# !git clone https://github.com/TruongDuyLongPTIT/CTQW-PRO-Quantum-Walk-Based-Metabolite-Disease-Prioritization.git /content/project

# Add src vào Python path
import sys
sys.path.insert(0, '/content/project/src')

# Install dependencies
# !pip install -q torch scikit-learn networkx tqdm
# Out:
# Cloning into '/content/project'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 246 (delta 19), reused 24 (delta 10), pack-reused 203 (from 1)
# Receiving objects: 100% (246/246), 1.18 MiB | 7.57 MiB/s, done.
# Resolving deltas: 100% (139/139), done.

# %%
from pathlib import Path
from google.colab import drive

if not Path('/content/drive/MyDrive').exists():
    drive.mount('/content/drive')
else:
    print("Drive đã mount sẵn.")
# Out:
# Mounted at /content/drive

# %%
# !python /content/project/experiments/01_main_results.py
# Out:
# ============================================================
# STEP 1 — Build graph
#   Graph: 2788 nodes, 22439 edges
#   G_pro: 2894 nodes (106 pathway), 31360 edges
#
# STEP 2 — Build eval sets
#   hmdb_to_recon: +0 IK, +331 name → 3286 total
#   Extracting SMPDB metabolites...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:26<00:00, 1862.54it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#   eval_set1 (HMDB+CTD): 158 diseases
#   eval_set2 (MarkerDB): 21 diseases
#   eval_set3 (SMPDB):    153 diseases
#
# STEP 3 — Eigendecomposition
#   Done.
#
# ============================================================
# [Table 1] RWR vs CTQW on G_cc...
# RWR/HMDB+CTD: 100% 158/158 [01:28<00:00,  1.78it/s]
# CTQW/HMDB+CTD: 100% 158/158 [03:38<00:00,  1.38s/it]
#   HMDB+CTD: 5.1 min
# RWR/MarkerDB: 100% 21/21 [00:15<00:00,  1.32it/s]
# CTQW/MarkerDB: 100% 21/21 [00:39<00:00,  1.88s/it]
#   MarkerDB: 0.9 min
# RWR/SMPDB: 100% 153/153 [01:03<00:00,  2.41it/s]
# CTQW/SMPDB: 100% 153/153 [02:45<00:00,  1.08s/it]
#   SMPDB: 3.8 min
#
# [Table 2] PROFANCY vs CTQW-PRO on G_pro...
# PROFANCY/HMDB+CTD: 100% 158/158 [01:40<00:00,  1.58it/s]
# CTQW-PRO/HMDB+CTD: 100% 158/158 [04:16<00:00,  1.63s/it]
#   HMDB+CTD: 6.0 min
# PROFANCY/MarkerDB: 100% 21/21 [00:17<00:00,  1.20it/s]
# CTQW-PRO/MarkerDB: 100% 21/21 [00:47<00:00,  2.28s/it]
#   MarkerDB: 1.1 min
# PROFANCY/SMPDB: 100% 153/153 [01:14<00:00,  2.04it/s]
# CTQW-PRO/SMPDB: 100% 153/153 [03:17<00:00,  1.29s/it]
#   SMPDB: 4.5 min
#
# [Table 3] NH-CTQW-PRO...
#   Building NH eigendecomp (γ=22.0)... 51.8s
# NH/HMDB+CTD: 100% 158/158 [00:48<00:00,  3.26it/s]
#   HMDB+CTD: 0.8 min
# NH/MarkerDB: 100% 21/21 [00:07<00:00,  2.71it/s]
#   MarkerDB: 0.1 min
# NH/SMPDB: 100% 153/153 [00:34<00:00,  4.38it/s]
#   SMPDB: 0.6 min
#
# [Table 4] Driven CTQW-PRO & RRF...
# Driven/HMDB+CTD: 100% 158/158 [08:26<00:00,  3.21s/it]
# RRF/HMDB+CTD: 100% 158/158 [09:05<00:00,  3.45s/it]
#   HMDB+CTD: 17.5 min
# Driven/MarkerDB: 100% 21/21 [01:31<00:00,  4.36s/it]
# RRF/MarkerDB: 100% 21/21 [01:40<00:00,  4.80s/it]
#   MarkerDB: 3.2 min
# Driven/SMPDB: 100% 153/153 [06:22<00:00,  2.50s/it]
# RRF/SMPDB: 100% 153/153 [06:50<00:00,  2.68s/it]
#   SMPDB: 13.2 min
#
# ========================================================================
# TABLE 1: RWR vs CTQW (G_cc)
#
# === HMDB+CTD (n=158) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.7872   0.0158  0.0080  0.0240  0.0798
# CTQW                     0.7621   0.0510  0.0770  0.1176  0.1767 ◄
#
# === MarkerDB (n=21) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.8541   0.0279  0.0115  0.0386  0.1365
# CTQW                     0.8414   0.0755  0.1063  0.1695  0.2446 ◄
#
# === SMPDB (n=153) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.9421   0.0488  0.0307  0.1157  0.3830
# CTQW                     0.9310   0.1925  0.2738  0.3514  0.4790 ◄
#
# ========================================================================
# TABLE 2: PROFANCY vs CTQW-PRO (G_pro)
#
# === HMDB+CTD (n=158) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8261   0.0161  0.0059  0.0251  0.0879
# t=0.1                    0.8195   0.0598  0.0848  0.1340  0.1915 ◄
#
# === MarkerDB (n=21) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8837   0.0287  0.0115  0.0465  0.1321
# t=0.1                    0.8835   0.0850  0.1299  0.1858  0.2646 ◄
#
# === SMPDB (n=153) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9543   0.0492  0.0273  0.1115  0.3691
# t=0.1                    0.9568   0.2172  0.3078  0.4177  0.5429 ◄
#
# ========================================================================
# TABLE 3: CTQW-PRO vs NH-CTQW-PRO (G_pro)
#
# === HMDB+CTD (n=158) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8195   0.0598  0.0848  0.1340  0.1915
# NH γ=22.0                0.8216   0.0658  0.0955  0.1450  0.2010 ◄
#
# === MarkerDB (n=21) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8835   0.0850  0.1299  0.1858  0.2646
# NH γ=22.0                0.8877   0.0918  0.1260  0.1923  0.2622 ◄
#
# === SMPDB (n=153) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.9568   0.2172  0.3078  0.4177  0.5429
# NH γ=22.0                0.9600   0.2618  0.3864  0.4810  0.5793 ◄
#
# ========================================================================
# TABLE 4: CTQW-PRO vs Driven vs RRF (G_pro)
#
# === HMDB+CTD (n=158) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8195   0.0598  0.0848  0.1340  0.1915
# driven_s2_a0.5           0.7973   0.0594  0.0853  0.1459  0.1913
# RRF                      0.8168   0.0686  0.0970  0.1480  0.2001 ◄
#
# === MarkerDB (n=21) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8835   0.0850  0.1299  0.1858  0.2646
# driven_s2_a0.5           0.8749   0.0775  0.1106  0.1605  0.2225
# RRF                      0.8882   0.0869  0.1192  0.1711  0.2356
#
# === SMPDB (n=153) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.9568   0.2172  0.3078  0.4177  0.5429
# driven_s2_a0.5           0.9553   0.2661  0.3905  0.4887  0.5929 ◄
# RRF                      0.9612   0.2592  0.4046  0.5067  0.6155 ◄
#
# ========================================================================
# WILCOXON: CTQW vs RWR
#
# --- HMDB+CTD (n=158) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.7872+/-0.0997   0.7621+/-0.1188  -0.0251  1.557e-08  ***
#   mrr        0.0158+/-0.0195   0.0510+/-0.0804  +0.0351  1.929e-14  ***
#   r@5        0.0080+/-0.0348   0.0770+/-0.1446  +0.0690  1.629e-09  ***
#   r@10       0.0240+/-0.0753   0.1176+/-0.1869  +0.0936  4.567e-10  ***
#   r@20       0.0798+/-0.1520   0.1767+/-0.2225  +0.0969  2.056e-11  ***
#   r@50       0.2186+/-0.2409   0.2538+/-0.2433  +0.0353  0.0003336  ***
#
# --- MarkerDB (n=21) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.8541+/-0.0973   0.8414+/-0.0918  -0.0127     0.4932  ns
#   mrr        0.0279+/-0.0255   0.0755+/-0.0727  +0.0476   0.001184  **
#   r@5        0.0115+/-0.0293   0.1063+/-0.1278  +0.0949    0.01325  *
#   r@10       0.0386+/-0.0620   0.1695+/-0.1596  +0.1308   0.008799  **
#   r@20       0.1365+/-0.1669   0.2446+/-0.1962  +0.1081    0.09392  .
#   r@50       0.3637+/-0.2146   0.3479+/-0.1963  -0.0158          1  ns
#
# --- SMPDB (n=153) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.9421+/-0.0315   0.9310+/-0.0413  -0.0111  1.594e-06  ***
#   mrr        0.0488+/-0.0316   0.1925+/-0.1272  +0.1438  4.465e-25  ***
#   r@5        0.0307+/-0.0896   0.2738+/-0.1944  +0.2432   2.61e-23  ***
#   r@10       0.1157+/-0.1634   0.3514+/-0.1960  +0.2357  6.333e-24  ***
#   r@20       0.3830+/-0.1898   0.4790+/-0.2004  +0.0960   4.47e-13  ***
#   r@50       0.6449+/-0.1528   0.6485+/-0.1332  +0.0037          1  ns
#
# WILCOXON: CTQW-PRO vs PROFANCY
#
# --- HMDB+CTD (n=158) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8261+/-0.0794   0.8195+/-0.1032  -0.0066          1  ns
#   mrr        0.0161+/-0.0200   0.0598+/-0.0898  +0.0437  7.555e-18  ***
#   r@5        0.0059+/-0.0322   0.0848+/-0.1489  +0.0789  2.386e-10  ***
#   r@10       0.0251+/-0.0830   0.1340+/-0.1924  +0.1088  1.359e-12  ***
#   r@20       0.0879+/-0.1582   0.1915+/-0.2252  +0.1036  4.234e-13  ***
#   r@50       0.2189+/-0.2397   0.2701+/-0.2449  +0.0511  5.298e-07  ***
#
# --- MarkerDB (n=21) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8837+/-0.0740   0.8835+/-0.0642  -0.0002          1  ns
#   mrr        0.0287+/-0.0255   0.0850+/-0.0780  +0.0563  0.0001888  ***
#   r@5        0.0115+/-0.0293   0.1299+/-0.1348  +0.1184   0.008813  **
#   r@10       0.0465+/-0.0759   0.1858+/-0.1549  +0.1393    0.01356  *
#   r@20       0.1321+/-0.1645   0.2646+/-0.1741  +0.1324    0.04296  *
#   r@50       0.3613+/-0.2130   0.3634+/-0.1756  +0.0021          1  ns
#
# --- SMPDB (n=153) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9543+/-0.0238   0.9568+/-0.0298  +0.0025    0.02267  *
#   mrr        0.0492+/-0.0309   0.2172+/-0.1246  +0.1680  4.289e-26  ***
#   r@5        0.0273+/-0.0798   0.3078+/-0.1727  +0.2805  8.576e-25  ***
#   r@10       0.1115+/-0.1599   0.4177+/-0.1966  +0.3062  8.899e-26  ***
#   r@20       0.3691+/-0.1976   0.5429+/-0.1736  +0.1738  3.018e-23  ***
#   r@50       0.6582+/-0.1659   0.6736+/-0.1450  +0.0154     0.2134  ns
#
# WILCOXON: NH vs CTQW-PRO
#
# --- HMDB+CTD (n=158) ---
#   Metric           CTQW-PRO        NH γ=22.0    Delta     p_bonf  Sig
#   auc        0.8195+/-0.1032   0.8216+/-0.1030  +0.0021     0.0317  *
#   mrr        0.0598+/-0.0898   0.0658+/-0.0931  +0.0060  4.172e-09  ***
#   r@5        0.0848+/-0.1489   0.0955+/-0.1568  +0.0106   0.003769  **
#   r@10       0.1340+/-0.1924   0.1450+/-0.1958  +0.0110     0.0186  *
#   r@20       0.1915+/-0.2252   0.2010+/-0.2301  +0.0095     0.0574  .
#   r@50       0.2701+/-0.2449   0.2707+/-0.2480  +0.0006          1  ns
#
# --- MarkerDB (n=21) ---
#   Metric           CTQW-PRO        NH γ=22.0    Delta     p_bonf  Sig
#   auc        0.8835+/-0.0642   0.8877+/-0.0636  +0.0041     0.2525  ns
#   mrr        0.0850+/-0.0780   0.0918+/-0.0804  +0.0068      0.276  ns
#   r@5        0.1299+/-0.1348   0.1260+/-0.1160  -0.0038          1  ns
#   r@10       0.1858+/-0.1549   0.1923+/-0.1575  +0.0065          1  ns
#   r@20       0.2646+/-0.1741   0.2622+/-0.1776  -0.0023          1  ns
#   r@50       0.3634+/-0.1756   0.3939+/-0.1934  +0.0305     0.5556  ns
#
# --- SMPDB (n=153) ---
#   Metric           CTQW-PRO        NH γ=22.0    Delta     p_bonf  Sig
#   auc        0.9568+/-0.0298   0.9600+/-0.0288  +0.0032  2.513e-09  ***
#   mrr        0.2172+/-0.1246   0.2618+/-0.1368  +0.0446  2.897e-23  ***
#   r@5        0.3078+/-0.1727   0.3864+/-0.2162  +0.0786   7.21e-12  ***
#   r@10       0.4177+/-0.1966   0.4810+/-0.2042  +0.0633  2.959e-13  ***
#   r@20       0.5429+/-0.1736   0.5793+/-0.2007  +0.0365  4.222e-05  ***
#   r@50       0.6736+/-0.1450   0.7078+/-0.1404  +0.0342  1.298e-11  ***
#
# WILCOXON: Driven & RRF vs CTQW-PRO
#
# --- HMDB+CTD (n=158) ---
#   Metric           CTQW-PRO           Driven    Delta     p_bonf  Sig
#   auc        0.8195+/-0.1032   0.7973+/-0.1128  -0.0222  1.356e-07  ***
#   mrr        0.0598+/-0.0898   0.0594+/-0.0853  -0.0004          1  ns
#   r@5        0.0848+/-0.1489   0.0853+/-0.1375  +0.0004          1  ns
#   r@10       0.1340+/-0.1924   0.1459+/-0.1990  +0.0119      0.191  ns
#   r@20       0.1915+/-0.2252   0.1913+/-0.2299  -0.0002          1  ns
#   r@50       0.2701+/-0.2449   0.2766+/-0.2591  +0.0065     0.9598  ns
#
# --- HMDB+CTD (n=158) ---
#   Metric           CTQW-PRO              RRF    Delta     p_bonf  Sig
#   auc        0.8195+/-0.1032   0.8168+/-0.1033  -0.0027     0.3585  ns
#   mrr        0.0598+/-0.0898   0.0686+/-0.0928  +0.0088  3.258e-05  ***
#   r@5        0.0848+/-0.1489   0.0970+/-0.1548  +0.0121    0.01219  *
#   r@10       0.1340+/-0.1924   0.1480+/-0.2000  +0.0141      0.024  *
#   r@20       0.1915+/-0.2252   0.2001+/-0.2345  +0.0086     0.5292  ns
#   r@50       0.2701+/-0.2449   0.2761+/-0.2570  +0.0060     0.5619  ns
#
# --- MarkerDB (n=21) ---
#   Metric           CTQW-PRO           Driven    Delta     p_bonf  Sig
#   auc        0.8835+/-0.0642   0.8749+/-0.0744  -0.0086          1  ns
#   mrr        0.0850+/-0.0780   0.0775+/-0.0687  -0.0075          1  ns
#   r@5        0.1299+/-0.1348   0.1106+/-0.1255  -0.0193          1  ns
#   r@10       0.1858+/-0.1549   0.1605+/-0.1413  -0.0253     0.9467  ns
#   r@20       0.2646+/-0.1741   0.2225+/-0.1544  -0.0421     0.3827  ns
#   r@50       0.3634+/-0.1756   0.3443+/-0.1659  -0.0191          1  ns
#
# --- MarkerDB (n=21) ---
#   Metric           CTQW-PRO              RRF    Delta     p_bonf  Sig
#   auc        0.8835+/-0.0642   0.8882+/-0.0682  +0.0047     0.7161  ns
#   mrr        0.0850+/-0.0780   0.0869+/-0.0792  +0.0019          1  ns
#   r@5        0.1299+/-0.1348   0.1192+/-0.1311  -0.0107          1  ns
#   r@10       0.1858+/-0.1549   0.1711+/-0.1419  -0.0147          1  ns
#   r@20       0.2646+/-0.1741   0.2356+/-0.1692  -0.0289     0.9467  ns
#   r@50       0.3634+/-0.1756   0.3799+/-0.1815  +0.0165          1  ns
#
# --- SMPDB (n=153) ---
#   Metric           CTQW-PRO           Driven    Delta     p_bonf  Sig
#   auc        0.9568+/-0.0298   0.9553+/-0.0356  -0.0015     0.8414  ns
#   mrr        0.2172+/-0.1246   0.2661+/-0.1467  +0.0489  0.0001326  ***
#   r@5        0.3078+/-0.1727   0.3905+/-0.2041  +0.0827   9.85e-11  ***
#   r@10       0.4177+/-0.1966   0.4887+/-0.1910  +0.0709  1.738e-12  ***
#   r@20       0.5429+/-0.1736   0.5929+/-0.1885  +0.0500   4.52e-08  ***
#   r@50       0.6736+/-0.1450   0.7348+/-0.1526  +0.0612  1.608e-11  ***
#
# --- SMPDB (n=153) ---
#   Metric           CTQW-PRO              RRF    Delta     p_bonf  Sig
#   auc        0.9568+/-0.0298   0.9612+/-0.0288  +0.0044  4.572e-13  ***
#   mrr        0.2172+/-0.1246   0.2592+/-0.1368  +0.0420  1.076e-09  ***
#   r@5        0.3078+/-0.1727   0.4046+/-0.1966  +0.0968  1.873e-13  ***
#   r@10       0.4177+/-0.1966   0.5067+/-0.2145  +0.0890  7.542e-16  ***
#   r@20       0.5429+/-0.1736   0.6155+/-0.1980  +0.0726  3.269e-12  ***
#   r@50       0.6736+/-0.1450   0.7256+/-0.1438  +0.0520  2.714e-13  ***
#
# --- Bootstrap 95% CI ---
#
#   AUC:
#     HMDB+CTD   PROFANCY             0.8261 [0.8143,0.8386]  n=158
#     MarkerDB   PROFANCY             0.8837 [0.8541,0.9172]  n=21
#     SMPDB      PROFANCY             0.9543 [0.9506,0.9579]  n=153
#     HMDB+CTD   CTQW-PRO             0.8195 [0.8042,0.8355]  n=158
#     MarkerDB   CTQW-PRO             0.8835 [0.8571,0.9100]  n=21
#     SMPDB      CTQW-PRO             0.9568 [0.9521,0.9610]  n=153
#     HMDB+CTD   NH γ=22.0            0.8216 [0.8056,0.8379]  n=158
#     MarkerDB   NH γ=22.0            0.8877 [0.8614,0.9142]  n=21
#     SMPDB      NH γ=22.0            0.9600 [0.9556,0.9642]  n=153
#     HMDB+CTD   Driven               0.7973 [0.7799,0.8146]  n=158
#     MarkerDB   Driven               0.8749 [0.8444,0.9050]  n=21
#     SMPDB      Driven               0.9553 [0.9497,0.9608]  n=153
#     HMDB+CTD   RRF                  0.8168 [0.8005,0.8326]  n=158
#     MarkerDB   RRF                  0.8882 [0.8589,0.9166]  n=21
#     SMPDB      RRF                  0.9612 [0.9567,0.9654]  n=153
#
#   MRR:
#     HMDB+CTD   PROFANCY             0.0161 [0.0131,0.0193]  n=158
#     MarkerDB   PROFANCY             0.0287 [0.0196,0.0412]  n=21
#     SMPDB      PROFANCY             0.0492 [0.0444,0.0543]  n=153
#     HMDB+CTD   CTQW-PRO             0.0598 [0.0461,0.0744]  n=158
#     MarkerDB   CTQW-PRO             0.0850 [0.0569,0.1230]  n=21
#     SMPDB      CTQW-PRO             0.2172 [0.1969,0.2379]  n=153
#     HMDB+CTD   NH γ=22.0            0.0658 [0.0514,0.0813]  n=158
#     MarkerDB   NH γ=22.0            0.0918 [0.0631,0.1283]  n=21
#     SMPDB      NH γ=22.0            0.2618 [0.2393,0.2827]  n=153
#     HMDB+CTD   Driven               0.0594 [0.0464,0.0735]  n=158
#     MarkerDB   Driven               0.0775 [0.0509,0.1091]  n=21
#     SMPDB      Driven               0.2661 [0.2429,0.2897]  n=153
#     HMDB+CTD   RRF                  0.0686 [0.0541,0.0836]  n=158
#     MarkerDB   RRF                  0.0869 [0.0565,0.1246]  n=21
#     SMPDB      RRF                  0.2592 [0.2376,0.2806]  n=153
#
#   R@20:
#     HMDB+CTD   PROFANCY             0.0879 [0.0638,0.1128]  n=158
#     MarkerDB   PROFANCY             0.1321 [0.0713,0.2078]  n=21
#     SMPDB      PROFANCY             0.3691 [0.3364,0.4028]  n=153
#     HMDB+CTD   CTQW-PRO             0.1915 [0.1554,0.2269]  n=158
#     MarkerDB   CTQW-PRO             0.2646 [0.1934,0.3395]  n=21
#     SMPDB      CTQW-PRO             0.5429 [0.5156,0.5708]  n=153
#     HMDB+CTD   NH γ=22.0            0.2010 [0.1652,0.2372]  n=158
#     MarkerDB   NH γ=22.0            0.2622 [0.1942,0.3409]  n=21
#     SMPDB      NH γ=22.0            0.5793 [0.5480,0.6121]  n=153
#     HMDB+CTD   Driven               0.1913 [0.1546,0.2277]  n=158
#     MarkerDB   Driven               0.2225 [0.1604,0.2885]  n=21
#     SMPDB      Driven               0.5929 [0.5627,0.6231]  n=153
#     HMDB+CTD   RRF                  0.2001 [0.1637,0.2368]  n=158
#     MarkerDB   RRF                  0.2356 [0.1697,0.3107]  n=21
#     SMPDB      RRF                  0.6155 [0.5843,0.6470]  n=153
#
# --- Win counts ---
#   Pair                         Dataset    Metric  A wins  B wins   tie     n
#   --------------------------------------------------------------------
#   CTQW vs RWR                  HMDB+CTD   auc         57     101     0   158
#   CTQW vs RWR                  MarkerDB   auc          5      16     0    21
#   CTQW vs RWR                  SMPDB      auc         60      93     0   153
#   CTQW vs RWR                  HMDB+CTD   mrr        115      43     0   158
#   CTQW vs RWR                  MarkerDB   mrr         18       3     0    21
#   CTQW vs RWR                  SMPDB      mrr        138      15     0   153
#   CTQW-PRO vs PROFANCY         HMDB+CTD   auc         91      67     0   158
#   CTQW-PRO vs PROFANCY         MarkerDB   auc          9      12     0    21
#   CTQW-PRO vs PROFANCY         SMPDB      auc        100      53     0   153
#   CTQW-PRO vs PROFANCY         HMDB+CTD   mrr        126      32     0   158
#   CTQW-PRO vs PROFANCY         MarkerDB   mrr         20       1     0    21
#   CTQW-PRO vs PROFANCY         SMPDB      mrr        153       0     0   153
#   NH γ=22.0 vs CTQW-PRO        HMDB+CTD   auc        100      57     1   158
#   NH γ=22.0 vs CTQW-PRO        MarkerDB   auc         15       6     0    21
#   NH γ=22.0 vs CTQW-PRO        SMPDB      auc        116      37     0   153
#   NH γ=22.0 vs CTQW-PRO        HMDB+CTD   mrr        119      39     0   158
#   NH γ=22.0 vs CTQW-PRO        MarkerDB   mrr         16       5     0    21
#   NH γ=22.0 vs CTQW-PRO        SMPDB      mrr        138      15     0   153
#   Driven vs CTQW-PRO           HMDB+CTD   auc         49     109     0   158
#   Driven vs CTQW-PRO           MarkerDB   auc         11      10     0    21
#   Driven vs CTQW-PRO           SMPDB      auc        101      52     0   153
#   Driven vs CTQW-PRO           HMDB+CTD   mrr         78      80     0   158
#   Driven vs CTQW-PRO           MarkerDB   mrr         10      11     0    21
#   Driven vs CTQW-PRO           SMPDB      mrr         94      59     0   153
#   RRF vs CTQW-PRO              HMDB+CTD   auc         69      89     0   158
#   RRF vs CTQW-PRO              MarkerDB   auc         13       8     0    21
#   RRF vs CTQW-PRO              SMPDB      auc        119      34     0   153
#   RRF vs CTQW-PRO              HMDB+CTD   mrr        100      58     0   158
#   RRF vs CTQW-PRO              MarkerDB   mrr         14       7     0    21
#   RRF vs CTQW-PRO              SMPDB      mrr        114      39     0   153
#
# Saving...
#   Saved: /content/drive/MyDrive/CTQW for metabolites/results/main_results.csv
#   Saved: /content/drive/MyDrive/CTQW for metabolites/results/wilcoxon_results.csv
#   Saved: /content/drive/MyDrive/CTQW for metabolites/results/win_counts.csv
# Done.

# %%
# !python /content/project/experiments/02_ablation_graph.py
# Out:
# Building graphs...
#   G_pro: 2894 → clean: 2851 nodes
# Building eval sets...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:30<00:00, 1587.66it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
# Eigendecomposition...
#
# Running ablation...
# PROF_o/HMDB+CTD: 100% 158/158 [01:38<00:00,  1.61it/s]
# CTQW_o/HMDB+CTD: 100% 158/158 [04:20<00:00,  1.65s/it]
# PROF_c/HMDB+CTD: 100% 158/158 [01:39<00:00,  1.59it/s]
# CTQW_c/HMDB+CTD: 100% 158/158 [04:55<00:00,  1.87s/it]
#   HMDB+CTD: 12.6 min
# PROF_o/MarkerDB: 100% 21/21 [00:19<00:00,  1.09it/s]
# CTQW_o/MarkerDB: 100% 21/21 [00:46<00:00,  2.22s/it]
# PROF_c/MarkerDB: 100% 21/21 [00:18<00:00,  1.13it/s]
# CTQW_c/MarkerDB: 100% 21/21 [00:53<00:00,  2.55s/it]
#   MarkerDB: 2.3 min
# PROF_o/SMPDB: 100% 153/153 [01:11<00:00,  2.13it/s]
# CTQW_o/SMPDB: 100% 153/153 [03:13<00:00,  1.26s/it]
# PROF_c/SMPDB: 100% 153/153 [01:14<00:00,  2.05it/s]
# CTQW_c/SMPDB: 100% 153/153 [03:43<00:00,  1.46s/it]
#   SMPDB: 9.4 min
#
# ========================================================================
# ABLATION: Original vs Clean G_pro
#
# === HMDB+CTD ===
# Method             AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# -----------------------------------------------------------------
# PROFANCY             0.8261     0.0161     0.8370     0.0523  +0.0363
# CTQW-PRO             0.8195     0.0598     0.7813     0.0620  +0.0023
#
# === MarkerDB ===
# Method             AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# -----------------------------------------------------------------
# PROFANCY             0.8837     0.0287     0.9029     0.0753  +0.0467
# CTQW-PRO             0.8835     0.0850     0.8699     0.0859  +0.0009
#
# === SMPDB ===
# Method             AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# -----------------------------------------------------------------
# PROFANCY             0.9543     0.0492     0.9555     0.2567  +0.2076
# CTQW-PRO             0.9568     0.2172     0.9549     0.2668  +0.0496
#
# Saved: /content/drive/MyDrive/CTQW for metabolites/results/ablation_graph.csv
# Done.

# %%
# !python /content/project/experiments/03_mechanism_experiments.py
# Out:
# ============================================================
# Setup...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:26<00:00, 1867.61it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#   HMDB+CTD: 158 diseases
#   SMPDB:    153 diseases
#   Device: cpu
#
# ============================================================
# EXP 1: Self-loop leakage analysis (GPU-accelerated)
#   (A) Baseline:     no self-loops (γ=0)
#   (B) Leaked:       H = A_pro + 10.0·diag(ALL disease mets in G_pro)
#   (C) Leakage-free: H = A_pro + 10.0·diag(seed mets only, per fold)
#   Semantics of B: test_met receives self-loop → score artificially boosted
#   Dataset: full SMPDB (153 diseases)
#   NOTE: uses torch.linalg.eigh (symmetric H) for all 3 conditions
#   [ 10/153] elapsed=17.4m  ETA=249.5m | MRR  A=0.2561  B=0.3759  C=0.2379 | C_eigh=139.8s
#   [ 20/153] elapsed=38.8m  ETA=257.7m | MRR  A=0.2388  B=0.3278  C=0.2275 | C_eigh=69.1s
#   [ 30/153] elapsed=54.9m  ETA=225.3m | MRR  A=0.2460  B=0.3280  C=0.2335 | C_eigh=87.3s
#   [ 40/153] elapsed=73.5m  ETA=207.7m | MRR  A=0.2318  B=0.3154  C=0.2192 | C_eigh=83.4s
#   [ 50/153] elapsed=95.9m  ETA=197.6m | MRR  A=0.2250  B=0.3043  C=0.2136 | C_eigh=87.1s
#   [ 60/153] elapsed=114.3m  ETA=177.2m | MRR  A=0.2231  B=0.3069  C=0.2163 | C_eigh=89.7s
#   [ 70/153] elapsed=130.9m  ETA=155.2m | MRR  A=0.2192  B=0.3010  C=0.2149 | C_eigh=78.4s
#   [ 80/153] elapsed=145.7m  ETA=133.0m | MRR  A=0.2134  B=0.2962  C=0.2108 | C_eigh=133.2s
#   [ 90/153] elapsed=164.0m  ETA=114.8m | MRR  A=0.2065  B=0.2890  C=0.2035 | C_eigh=47.4s
#   [100/153] elapsed=178.2m  ETA=94.5m | MRR  A=0.2155  B=0.2974  C=0.2130 | C_eigh=66.2s
#   [110/153] elapsed=195.5m  ETA=76.4m | MRR  A=0.2104  B=0.2925  C=0.2076 | C_eigh=78.6s
#   [120/153] elapsed=210.0m  ETA=57.7m | MRR  A=0.2061  B=0.2850  C=0.2034 | C_eigh=66.7s
#   [130/153] elapsed=228.7m  ETA=40.5m | MRR  A=0.2127  B=0.2916  C=0.2117 | C_eigh=73.3s
#   [140/153] elapsed=245.4m  ETA=22.8m | MRR  A=0.2093  B=0.2870  C=0.2092 | C_eigh=87.4s
#   [150/153] elapsed=262.5m  ETA=5.2m | MRR  A=0.2137  B=0.2922  C=0.2136 | C_eigh=114.3s
#   [153/153] elapsed=267.0m  ETA=0.0m | MRR  A=0.2173  B=0.2959  C=0.2166 | C_eigh=82.3s
# EXP1: 100%|███████████████████████████| 153/153 [4:26:58<00:00, 104.69s/disease]
#
#   Done: 153 diseases | total = 267.0 min
#
#   Condition                             AUC      MRR     R@20
#   ------------------------------------------------------------
#   (A) Baseline (γ=0)                 0.9568   0.2173   0.5429
#   (B) Self-loop LEAKED               0.9650   0.2959   0.5869  ← inflated
#   (C) Self-loop leakage-free         0.9567   0.2166   0.5088
#
#   ΔMRR (B vs A): +0.0786  ← leakage artifact
#   ΔMRR (C vs A): -0.0007  ← true self-loop effect
#   → Leakage confirmed: B inflates by 0.0793 MRR over C
#
# ============================================================
# EXP 2: Dispersion analysis (Jaccard dissimilarity)
#   Hypothesis: CTQW-PRO improves MORE when seeds are dispersed
#
#   [HMDB+CTD] P25=0.686 → CONCENTRATED: 40 | P75=0.744 → DISPERSED: 40
# PROFANCY/HMDB+CTD/CONCENTRATED: 100% 40/40 [00:17<00:00,  2.34it/s]
# CTQW-PRO/HMDB+CTD/CONCENTRATED: 100% 40/40 [00:49<00:00,  1.24s/it]
#   HMDB+CTD   CONCENTRATED   PROFANCY=0.0281  CTQW-PRO=0.1092  ΔMRR=+0.0811  (n=40)
#
# --- HMDB+CTD/CONCENTRATED (n=40) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8664+/-0.0841   0.8731+/-0.0876  +0.0068     0.3289  ns
#   mrr        0.0281+/-0.0332   0.1092+/-0.1346  +0.0811  2.221e-08  ***
#   r@5        0.0198+/-0.0608   0.1519+/-0.2140  +0.1321   0.002129  **
#   r@10       0.0697+/-0.1431   0.2275+/-0.2780  +0.1578  0.0007885  ***
#   r@20       0.1831+/-0.2464   0.3042+/-0.3121  +0.1211  0.0004318  ***
#   r@50       0.3270+/-0.3384   0.3826+/-0.3192  +0.0556    0.04692  *
# PROFANCY/HMDB+CTD/DISPERSED: 100% 40/40 [00:21<00:00,  1.83it/s]
# CTQW-PRO/HMDB+CTD/DISPERSED: 100% 40/40 [01:01<00:00,  1.53s/it]
#   HMDB+CTD   DISPERSED      PROFANCY=0.0109  CTQW-PRO=0.0460  ΔMRR=+0.0351  (n=40)
#
# --- HMDB+CTD/DISPERSED (n=40) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7779+/-0.0703   0.7402+/-0.1172  -0.0377    0.09904  .
#   mrr        0.0109+/-0.0082   0.0460+/-0.0606  +0.0351   0.004053  **
#   r@5        0.0007+/-0.0043   0.0567+/-0.0925  +0.0560   0.005872  **
#   r@10       0.0076+/-0.0222   0.0967+/-0.1291  +0.0892   0.001175  **
#   r@20       0.0525+/-0.0844   0.1282+/-0.1516  +0.0757    0.00442  **
#   r@50       0.1706+/-0.1591   0.1908+/-0.1806  +0.0202          1  ns
#
#   [SMPDB] P25=0.674 → CONCENTRATED: 40 | P75=0.759 → DISPERSED: 29
# PROFANCY/SMPDB/CONCENTRATED: 100% 40/40 [00:21<00:00,  1.89it/s]
# CTQW-PRO/SMPDB/CONCENTRATED: 100% 40/40 [00:58<00:00,  1.46s/it]
#   SMPDB      CONCENTRATED   PROFANCY=0.0532  CTQW-PRO=0.2252  ΔMRR=+0.1719  (n=40)
#
# --- SMPDB/CONCENTRATED (n=40) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9650+/-0.0166   0.9668+/-0.0275  +0.0018    0.01681  *
#   mrr        0.0532+/-0.0496   0.2252+/-0.1508  +0.1719  1.768e-07  ***
#   r@5        0.0538+/-0.1268   0.2955+/-0.1862  +0.2416  1.942e-07  ***
#   r@10       0.1090+/-0.2457   0.3766+/-0.2164  +0.2676  1.768e-07  ***
#   r@20       0.3249+/-0.1772   0.5374+/-0.1883  +0.2124  1.768e-07  ***
#   r@50       0.6992+/-0.1640   0.6711+/-0.1576  -0.0281     0.5676  ns
# PROFANCY/SMPDB/DISPERSED: 100% 29/29 [00:11<00:00,  2.46it/s]
# CTQW-PRO/SMPDB/DISPERSED: 100% 29/29 [00:35<00:00,  1.22s/it]
#   SMPDB      DISPERSED      PROFANCY=0.0534  CTQW-PRO=0.1753  ΔMRR=+0.1219  (n=29)
#
# --- SMPDB/DISPERSED (n=29) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9571+/-0.0246   0.9559+/-0.0297  -0.0012          1  ns
#   mrr        0.0534+/-0.0303   0.1753+/-0.0882  +0.1219  1.435e-05  ***
#   r@5        0.0315+/-0.0779   0.2689+/-0.1878  +0.2373  3.108e-05  ***
#   r@10       0.1575+/-0.1721   0.3304+/-0.1977  +0.1730  0.0005941  ***
#   r@20       0.3876+/-0.1738   0.4875+/-0.1293  +0.0999  0.0003088  ***
#   r@50       0.6536+/-0.1296   0.6680+/-0.1634  +0.0143          1  ns
#
#   KEY FINDING:
#   CONCENTRATED (HMDB+CTD): ΔMRR=+0.0811
#   CONCENTRATED (SMPDB): ΔMRR=+0.1719
#   DISPERSED    (HMDB+CTD): ΔMRR=+0.0351
#   DISPERSED    (SMPDB): ΔMRR=+0.1219
#   → Hypothesis REJECTED: CTQW-PRO improves MORE when seeds are CONCENTRATED
#   Saved: dispersion_analysis.csv
# Setup (chỉ dữ liệu + eigen-decomposition, không chạy eval)...
#   HMDB+CTD: 158 diseases
# Setup xong. Có sẵn: eval_set1, idx_pro, N_PRO, N, Apro_eigvecs,
# Apro_eigvals, _ph_fixed, RNG, N_MC
# -> Có thể chạy thẳng check_sigma5_direct.py ngay sau đoạn này.
#
# ============================================================
# EXP 3: Dephasing walk (decoherence experiment)
# Test seed set: 'Eosinophilic esophagitis'  (n_seeds=142)
#
# sigma       mean L2 dist         std   xu hướng
# ----------------------------------------------------
# 0.1             0.055228    0.000007
# 0.5             0.043426    0.000046   giảm
# 1.0             0.020519    0.000094   giảm
# 2.0             0.001224    0.000065   giảm
# 3.0             0.000637    0.000146   giảm
# 5.0             0.000582    0.000117   giảm
#
# ============================================================
# EXP 4: Chiral Quantum Walk
#   Hypothesis: directed reaction information improves walk
#   Directed edges: 11099/31360 (35.4%)
# Chiral φ=0: 100% 153/153 [04:05<00:00,  1.61s/it]
# Chiral φ=π/8: 100% 153/153 [01:39<00:00,  1.53it/s]
# Chiral φ=π/4: 100% 153/153 [01:39<00:00,  1.53it/s]
# Chiral φ=π/3: 100% 153/153 [01:39<00:00,  1.53it/s]
# Chiral φ=π/2: 100% 153/153 [01:38<00:00,  1.55it/s]
#
#   φ           AUC      MRR    R@20
#   ----------------------------
#   0        0.9568   0.2172  0.5429
#   π/8      0.9462   0.1858  0.5095
#   π/4      0.9444   0.1624  0.4762
#   π/3      0.9337   0.1367  0.4280
#   π/2      0.9289   0.1740  0.4807
#   Chiral walk does NOT improve (best φ=0, ΔMRR=+0.0000).
#   Reason: only 11099/31360 directed edges — graph not sufficiently asymmetric.
#
# Done.

# %%
# !python /content/project/experiments/04_biological_interpretability.py
# Out:
# =================================================================
# 06 — Biological Interpretability Analysis
# =================================================================
# Setup...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:28<00:00, 1702.96it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#
# Building NH-CTQW-PRO (γ=22.0, t=0.1)...
#   Done in 52.0s
#
# =================================================================
# DISEASE: Lesch-Nyhan Syndrome (LNS)  [LNS]
# =================================================================
#
# Seeds (n=24) — known disease metabolites:
#     #  Name                                                         HMDB  HMDB link
#   -----------------------------------------------------------------------------------------------
#     1. (S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate    HMDB0000797  https://hmdb.ca/metabolites/HMDB0000797
#     2. Adenine                                               HMDB0000034  https://hmdb.ca/metabolites/HMDB0000034
#     3. Adenosine                                             HMDB0004402  https://hmdb.ca/metabolites/HMDB0004402
#     4. 5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide    HMDB0001517  https://hmdb.ca/metabolites/HMDB0001517
#     5. L-Aspartate                                           HMDB0062186  https://hmdb.ca/metabolites/HMDB0062186
#     6. CAMP C10H11N5O6P                                      HMDB0000058  https://hmdb.ca/metabolites/HMDB0000058
#     7. Deoxyadenosine                                        HMDB0005778  https://hmdb.ca/metabolites/HMDB0005778
#     8. Deoxyguanosine                                        HMDB0000085  https://hmdb.ca/metabolites/HMDB0000085
#     9. Deoxyinosine                                          HMDB0000071  https://hmdb.ca/metabolites/HMDB0000071
#    10. Fumarate                                              HMDB0000134  https://hmdb.ca/metabolites/HMDB0000134
#    11. L-Glutamine                                           HMDB0000641  https://hmdb.ca/metabolites/HMDB0000641
#    12. L-Glutamate                                           HMDB0000148  https://hmdb.ca/metabolites/HMDB0000148
#    13. Glycine                                               HMDB0000123  https://hmdb.ca/metabolites/HMDB0000123
#    14. Guanosine                                             HMDB0000133  https://hmdb.ca/metabolites/HMDB0000133
#    15. Guanine                                               HMDB0000132  https://hmdb.ca/metabolites/HMDB0000132
#    16. Hypoxanthine                                          HMDB0000157  https://hmdb.ca/metabolites/HMDB0000157
#    17. IMP C10H11N4O8P                                       HMDB0000175  https://hmdb.ca/metabolites/HMDB0000175
#    18. Inosine                                               HMDB0000195  https://hmdb.ca/metabolites/HMDB0000195
#    19. Potassium                                             HMDB0000586  https://hmdb.ca/metabolites/HMDB0000586
#    20. 5-Phospho-alpha-D-ribose 1-diphosphate                HMDB0000280  https://hmdb.ca/metabolites/HMDB0000280
#    21. Alpha-D-Ribose 1-phosphate                            HMDB0001489  https://hmdb.ca/metabolites/HMDB0001489
#    22. Urate C5H4N4O3                                        HMDB0000289  https://hmdb.ca/metabolites/HMDB0000289
#    23. Xanthine                                              HMDB0000292  https://hmdb.ca/metabolites/HMDB0000292
#    24. Xanthosine                                            HMDB0000299  https://hmdb.ca/metabolites/HMDB0000299
#
# Top-20 predictions (NH-CTQW-PRO, full-seed mode):
#   Rank  Name                                                         HMDB       Score  PubMed search
#   --------------------------------------------------------------------------------------------------------------
#      1. 2-Deoxy-D-ribose 1-phosphate                          HMDB0001351    0.010913  https://pubmed.ncbi.nlm.nih.gov/?term=2-Deoxy-D-ribose+1-phosphate+Lesch-Nyhan+Syndrome+(LNS)
#      2. Xanthosine 5'-phosphate                               HMDB0001554    0.009688  https://pubmed.ncbi.nlm.nih.gov/?term=Xanthosine+5'-phosphate+Lesch-Nyhan+Syndrome+(LNS)
#      3. 5-Phospho-beta-D-ribosylamine                         HMDB0001128    0.002937  https://pubmed.ncbi.nlm.nih.gov/?term=5-Phospho-beta-D-ribosylamine+Lesch-Nyhan+Syndrome+(LNS)
#      4. N6-(1,2-Dicarboxyethyl)-AMP                           HMDB0001332    0.002526  https://pubmed.ncbi.nlm.nih.gov/?term=N6-(1,2-Dicarboxyethyl)-AMP+Lesch-Nyhan+Syndrome+(LNS)
#      5. 2-Oxoglutarate                                        HMDB0000208    0.002445  https://pubmed.ncbi.nlm.nih.gov/?term=2-Oxoglutarate+Lesch-Nyhan+Syndrome+(LNS)
#      6. Uracil                                                HMDB0000300    0.002119  https://pubmed.ncbi.nlm.nih.gov/?term=Uracil+Lesch-Nyhan+Syndrome+(LNS)
#      7. Uridine                                               HMDB0000296    0.001934  https://pubmed.ncbi.nlm.nih.gov/?term=Uridine+Lesch-Nyhan+Syndrome+(LNS)
#      8. L-Cysteine                                            HMDB0000574    0.001576  https://pubmed.ncbi.nlm.nih.gov/?term=L-Cysteine+Lesch-Nyhan+Syndrome+(LNS)
#      9. L-Histidine                                           HMDB0000177    0.001560  https://pubmed.ncbi.nlm.nih.gov/?term=L-Histidine+Lesch-Nyhan+Syndrome+(LNS)
#     10. Nicotinate                                            HMDB0001488    0.001533  https://pubmed.ncbi.nlm.nih.gov/?term=Nicotinate+Lesch-Nyhan+Syndrome+(LNS)
#     11. L-Alanine                                             HMDB0000161    0.001469  https://pubmed.ncbi.nlm.nih.gov/?term=L-Alanine+Lesch-Nyhan+Syndrome+(LNS)
#     12. L-Asparagine                                          HMDB0000168    0.001386  https://pubmed.ncbi.nlm.nih.gov/?term=L-Asparagine+Lesch-Nyhan+Syndrome+(LNS)
#     13. Deoxyuridine                                          HMDB0000012    0.001383  https://pubmed.ncbi.nlm.nih.gov/?term=Deoxyuridine+Lesch-Nyhan+Syndrome+(LNS)
#     14. Alpha-D-Ribose 5-phosphate                                           0.001369  https://pubmed.ncbi.nlm.nih.gov/?term=Alpha-D-Ribose+5-phosphate+Lesch-Nyhan+Syndrome+(LNS)
#     15. 5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide    HMDB0062708    0.001276  https://pubmed.ncbi.nlm.nih.gov/?term=5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide+Lesch-Nyhan+Syndrome+(LNS)
#     16. L-Lysine                                              HMDB0003405    0.001207  https://pubmed.ncbi.nlm.nih.gov/?term=L-Lysine+Lesch-Nyhan+Syndrome+(LNS)
#     17. Nicotinamide                                          HMDB0001406    0.001134  https://pubmed.ncbi.nlm.nih.gov/?term=Nicotinamide+Lesch-Nyhan+Syndrome+(LNS)
#     18. 5,6,7,8-Tetrahydrofolate                                             0.001111  https://pubmed.ncbi.nlm.nih.gov/?term=5,6,7,8-Tetrahydrofolate+Lesch-Nyhan+Syndrome+(LNS)
#     19. L-Methionine                                          HMDB0000696    0.001086  https://pubmed.ncbi.nlm.nih.gov/?term=L-Methionine+Lesch-Nyhan+Syndrome+(LNS)
#     20. 5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate    HMDB0006273    0.001072  https://pubmed.ncbi.nlm.nih.gov/?term=5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate+Lesch-Nyhan+Syndrome+(LNS)
#
#   → Verify each prediction at the PubMed links above.
#     Fill tier/pmid/direct_quote columns in the output CSV.
#
# =================================================================
# DISEASE: Alkaptonuria  [AKU]
# =================================================================
#
# Seeds (n=25) — known disease metabolites:
#     #  Name                                                         HMDB  HMDB link
#   -----------------------------------------------------------------------------------------------
#     1. 3,4-Dihydroxyphenylethyleneglycol                     HMDB0000318  https://hmdb.ca/metabolites/HMDB0000318
#     2. 3-4-Dihydroxyphenylacetate                            HMDB0001336  https://hmdb.ca/metabolites/HMDB0001336
#     3. 3-(4-Hydroxyphenyl)pyruvate                           HMDB0000707  https://hmdb.ca/metabolites/HMDB0000707
#     4. 3-Methoxytyramine                                     HMDB0006022  https://hmdb.ca/metabolites/HMDB0006022
#     5. Acetoacetate                                          HMDB0000060  https://hmdb.ca/metabolites/HMDB0000060
#     6. S-Adenosyl-L-homocysteine                             HMDB0000939  https://hmdb.ca/metabolites/HMDB0000939
#     7. 2-Oxoglutarate                                        HMDB0000208  https://hmdb.ca/metabolites/HMDB0000208
#     8. S-Adenosyl-L-methionine                               HMDB0001185  https://hmdb.ca/metabolites/HMDB0001185
#     9. L-Ascorbate                                           HMDB0029945  https://hmdb.ca/metabolites/HMDB0029945
#    10. L-Aspartate                                           HMDB0062186  https://hmdb.ca/metabolites/HMDB0062186
#    11. Dehydroascorbate                                      HMDB0062706  https://hmdb.ca/metabolites/HMDB0062706
#    12. Dopamine                                              HMDB0000073  https://hmdb.ca/metabolites/HMDB0000073
#    13. Fumarate                                              HMDB0000134  https://hmdb.ca/metabolites/HMDB0000134
#    14. L-Glutamate                                           HMDB0000148  https://hmdb.ca/metabolites/HMDB0000148
#    15. Homogentisate C8H7O4                                  HMDB0000130  https://hmdb.ca/metabolites/HMDB0000130
#    16. Melanin c                                             HMDB0004068  https://hmdb.ca/metabolites/HMDB0004068
#    17. Metanephrine                                          HMDB0004063  https://hmdb.ca/metabolites/HMDB0004063
#    18. Methylamine                                           HMDB0002983  https://hmdb.ca/metabolites/HMDB0002983
#    19. L-Normetanephrine                                     HMDB0000819  https://hmdb.ca/metabolites/HMDB0000819
#    20. Norepinephrine                                        HMDB0000216  https://hmdb.ca/metabolites/HMDB0000216
#    21. Oxaloacetate                                          HMDB0000223  https://hmdb.ca/metabolites/HMDB0000223
#    22. Pyridoxal 5'-phosphate                                HMDB0001491  https://hmdb.ca/metabolites/HMDB0001491
#    23. Tetrahydrobiopterin                                   HMDB0059658  https://hmdb.ca/metabolites/HMDB0059658
#    24. Tyramine                                              HMDB0062629  https://hmdb.ca/metabolites/HMDB0062629
#    25. L-Tyrosine                                            HMDB0000647  https://hmdb.ca/metabolites/HMDB0000647
#
# Top-20 predictions (NH-CTQW-PRO, full-seed mode):
#   Rank  Name                                                         HMDB       Score  PubMed search
#   --------------------------------------------------------------------------------------------------------------
#      1. Adrenaline                                                           0.006020  https://pubmed.ncbi.nlm.nih.gov/?term=Adrenaline+Alkaptonuria
#      2. 3,4-Dihydroxy-L-phenylalanine                                        0.005067  https://pubmed.ncbi.nlm.nih.gov/?term=3,4-Dihydroxy-L-phenylalanine+Alkaptonuria
#      3. Glycine                                               HMDB0000123    0.003922  https://pubmed.ncbi.nlm.nih.gov/?term=Glycine+Alkaptonuria
#      4. Pyruvate                                              HMDB0000243    0.003482  https://pubmed.ncbi.nlm.nih.gov/?term=Pyruvate+Alkaptonuria
#      5. 4 Hydroxy 2 oxoglutarate C5H4O6                       HMDB0002070    0.003069  https://pubmed.ncbi.nlm.nih.gov/?term=4+Hydroxy+2+oxoglutarate+C5H4O6+Alkaptonuria
#      6. L erythro 4 Hydroxyglutamate C5H8NO5                  HMDB0062752    0.003046  https://pubmed.ncbi.nlm.nih.gov/?term=L+erythro+4+Hydroxyglutamate+C5H8NO5+Alkaptonuria
#      7. Homovanillate                                                        0.002709  https://pubmed.ncbi.nlm.nih.gov/?term=Homovanillate+Alkaptonuria
#      8. 3-Methoxy-4-hydroxyphenylglycolaldehyde               HMDB0004061    0.002674  https://pubmed.ncbi.nlm.nih.gov/?term=3-Methoxy-4-hydroxyphenylglycolaldehyde+Alkaptonuria
#      9. 3,4-Dihydroxymandelaldehyde                           HMDB0004057    0.002544  https://pubmed.ncbi.nlm.nih.gov/?term=3,4-Dihydroxymandelaldehyde+Alkaptonuria
#     10. 3-O-methyldopa                                        HMDB0060747    0.002334  https://pubmed.ncbi.nlm.nih.gov/?term=3-O-methyldopa+Alkaptonuria
#     11. L-Glutamine                                           HMDB0000641    0.002090  https://pubmed.ncbi.nlm.nih.gov/?term=L-Glutamine+Alkaptonuria
#     12. L-Cysteine                                            HMDB0000574    0.002064  https://pubmed.ncbi.nlm.nih.gov/?term=L-Cysteine+Alkaptonuria
#     13. (-)-Salsolinol                                        HMDB0042012    0.001941  https://pubmed.ncbi.nlm.nih.gov/?term=(-)-Salsolinol+Alkaptonuria
#     14. N-methylsalsolinol                                    HMDB0003892    0.001853  https://pubmed.ncbi.nlm.nih.gov/?term=N-methylsalsolinol+Alkaptonuria
#     15. Formate                                               HMDB0000142    0.001672  https://pubmed.ncbi.nlm.nih.gov/?term=Formate+Alkaptonuria
#     16. Tetrahydrobiopterin-4a-carbinolamine                                 0.001548  https://pubmed.ncbi.nlm.nih.gov/?term=Tetrahydrobiopterin-4a-carbinolamine+Alkaptonuria
#     17. Triiodothyronine                                                     0.001443  https://pubmed.ncbi.nlm.nih.gov/?term=Triiodothyronine+Alkaptonuria
#     18. Succinate                                             HMDB0000254    0.001384  https://pubmed.ncbi.nlm.nih.gov/?term=Succinate+Alkaptonuria
#     19. 3,4-Dihydroxyphenylacetaldehyde                       HMDB0006778    0.001361  https://pubmed.ncbi.nlm.nih.gov/?term=3,4-Dihydroxyphenylacetaldehyde+Alkaptonuria
#     20. Formaldehyde                                          HMDB0001426    0.001358  https://pubmed.ncbi.nlm.nih.gov/?term=Formaldehyde+Alkaptonuria
#
#   → Verify each prediction at the PubMed links above.
#     Fill tier/pmid/direct_quote columns in the output CSV.
#
# =================================================================
# DISEASE: Maple Syrup Urine Disease  [MSUD]
# =================================================================
#
# Seeds (n=15) — known disease metabolites:
#     #  Name                                                         HMDB  HMDB link
#   -----------------------------------------------------------------------------------------------
#     1. 3-Methyl-2-oxobutanoate                               HMDB0004260  https://hmdb.ca/metabolites/HMDB0004260
#     2. 4-Methyl-2-oxopentanoate                              HMDB0000695  https://hmdb.ca/metabolites/HMDB0000695
#     3. Methylmalonate                                        HMDB0000202  https://hmdb.ca/metabolites/HMDB0000202
#     4. Acetoacetate                                          HMDB0000060  https://hmdb.ca/metabolites/HMDB0000060
#     5. 2-Oxoglutarate                                        HMDB0000208  https://hmdb.ca/metabolites/HMDB0000208
#     6. Biotin                                                HMDB0000030  https://hmdb.ca/metabolites/HMDB0000030
#     7. L-Glutamate                                           HMDB0000148  https://hmdb.ca/metabolites/HMDB0000148
#     8. L-Isoleucine                                          HMDB0000172  https://hmdb.ca/metabolites/HMDB0000172
#     9. L-Leucine                                             HMDB0000687  https://hmdb.ca/metabolites/HMDB0000687
#    10. Lipoamide C8H15NOS2                                   HMDB0000962  https://hmdb.ca/metabolites/HMDB0000962
#    11. Pyridoxal                                             HMDB0001545  https://hmdb.ca/metabolites/HMDB0001545
#    12. Pyridoxal 5'-phosphate                                HMDB0001491  https://hmdb.ca/metabolites/HMDB0001491
#    13. Succinate                                             HMDB0000254  https://hmdb.ca/metabolites/HMDB0000254
#    14. Thiamine diphosphate                                  HMDB0062636  https://hmdb.ca/metabolites/HMDB0062636
#    15. L-Valine                                              HMDB0000883  https://hmdb.ca/metabolites/HMDB0000883
#
# Top-20 predictions (NH-CTQW-PRO, full-seed mode):
#   Rank  Name                                                         HMDB       Score  PubMed search
#   --------------------------------------------------------------------------------------------------------------
#      1. (S)-3-Methyl-2-oxopentanoate                                         0.005397  https://pubmed.ncbi.nlm.nih.gov/?term=(S)-3-Methyl-2-oxopentanoate+Maple+Syrup+Urine+Disease
#      2. Glycine                                               HMDB0000123    0.005279  https://pubmed.ncbi.nlm.nih.gov/?term=Glycine+Maple+Syrup+Urine+Disease
#      3. L-Alanine                                             HMDB0000161    0.004321  https://pubmed.ncbi.nlm.nih.gov/?term=L-Alanine+Maple+Syrup+Urine+Disease
#      4. L-Glutamine                                           HMDB0000641    0.004063  https://pubmed.ncbi.nlm.nih.gov/?term=L-Glutamine+Maple+Syrup+Urine+Disease
#      5. L-Aspartate                                           HMDB0062186    0.003721  https://pubmed.ncbi.nlm.nih.gov/?term=L-Aspartate+Maple+Syrup+Urine+Disease
#      6. Succinyl-CoA                                          HMDB0001022    0.003398  https://pubmed.ncbi.nlm.nih.gov/?term=Succinyl-CoA+Maple+Syrup+Urine+Disease
#      7. L-Histidine                                           HMDB0000177    0.003312  https://pubmed.ncbi.nlm.nih.gov/?term=L-Histidine+Maple+Syrup+Urine+Disease
#      8. L-Tryptophan                                          HMDB0000929    0.003231  https://pubmed.ncbi.nlm.nih.gov/?term=L-Tryptophan+Maple+Syrup+Urine+Disease
#      9. L-Arginine                                            HMDB0062762    0.003225  https://pubmed.ncbi.nlm.nih.gov/?term=L-Arginine+Maple+Syrup+Urine+Disease
#     10. L-Cysteine                                            HMDB0000574    0.002875  https://pubmed.ncbi.nlm.nih.gov/?term=L-Cysteine+Maple+Syrup+Urine+Disease
#     11. L-Serine                                              HMDB0000589    0.002801  https://pubmed.ncbi.nlm.nih.gov/?term=L-Serine+Maple+Syrup+Urine+Disease
#     12. L-Phenylalanine                                       HMDB0000159    0.002785  https://pubmed.ncbi.nlm.nih.gov/?term=L-Phenylalanine+Maple+Syrup+Urine+Disease
#     13. L-Asparagine                                          HMDB0000168    0.002639  https://pubmed.ncbi.nlm.nih.gov/?term=L-Asparagine+Maple+Syrup+Urine+Disease
#     14. Succinic semialdehyde                                 HMDB0001259    0.002585  https://pubmed.ncbi.nlm.nih.gov/?term=Succinic+semialdehyde+Maple+Syrup+Urine+Disease
#     15. 2 Oxoadipate C6H6O5                                   HMDB0000225    0.002501  https://pubmed.ncbi.nlm.nih.gov/?term=2+Oxoadipate+C6H6O5+Maple+Syrup+Urine+Disease
#     16. L-Proline                                             HMDB0000162    0.002447  https://pubmed.ncbi.nlm.nih.gov/?term=L-Proline+Maple+Syrup+Urine+Disease
#     17. L-Threonine                                           HMDB0000167    0.002425  https://pubmed.ncbi.nlm.nih.gov/?term=L-Threonine+Maple+Syrup+Urine+Disease
#     18. 3-O-methyldopa                                        HMDB0060747    0.002372  https://pubmed.ncbi.nlm.nih.gov/?term=3-O-methyldopa+Maple+Syrup+Urine+Disease
#     19. Pyruvate                                              HMDB0000243    0.002362  https://pubmed.ncbi.nlm.nih.gov/?term=Pyruvate+Maple+Syrup+Urine+Disease
#     20. 2-Methyl-3-oxopropanoate                              HMDB0001172    0.002358  https://pubmed.ncbi.nlm.nih.gov/?term=2-Methyl-3-oxopropanoate+Maple+Syrup+Urine+Disease
#
#   → Verify each prediction at the PubMed links above.
#     Fill tier/pmid/direct_quote columns in the output CSV.
#
# =================================================================
# DISEASE: Phenylketonuria  [PKU]
# =================================================================
#
# Seeds (n=10) — known disease metabolites:
#     #  Name                                                         HMDB  HMDB link
#   -----------------------------------------------------------------------------------------------
#     1. 3-(4-Hydroxyphenyl)pyruvate                           HMDB0000707  https://hmdb.ca/metabolites/HMDB0000707
#     2. Acetoacetate                                          HMDB0000060  https://hmdb.ca/metabolites/HMDB0000060
#     3. 2-Oxoglutarate                                        HMDB0000208  https://hmdb.ca/metabolites/HMDB0000208
#     4. Fumarate                                              HMDB0000134  https://hmdb.ca/metabolites/HMDB0000134
#     5. L-Glutamate                                           HMDB0000148  https://hmdb.ca/metabolites/HMDB0000148
#     6. Homogentisate C8H7O4                                  HMDB0000130  https://hmdb.ca/metabolites/HMDB0000130
#     7. L-Phenylalanine                                       HMDB0000159  https://hmdb.ca/metabolites/HMDB0000159
#     8. Phenylpyruvate                                        HMDB0000205  https://hmdb.ca/metabolites/HMDB0000205
#     9. Pyridoxal 5'-phosphate                                HMDB0001491  https://hmdb.ca/metabolites/HMDB0001491
#    10. L-Tyrosine                                            HMDB0000647  https://hmdb.ca/metabolites/HMDB0000647
#
# Top-20 predictions (NH-CTQW-PRO, full-seed mode):
#   Rank  Name                                                         HMDB       Score  PubMed search
#   --------------------------------------------------------------------------------------------------------------
#      1. Glycine                                               HMDB0000123    0.006331  https://pubmed.ncbi.nlm.nih.gov/?term=Glycine+Phenylketonuria
#      2. L-Glutamine                                           HMDB0000641    0.005710  https://pubmed.ncbi.nlm.nih.gov/?term=L-Glutamine+Phenylketonuria
#      3. Succinate                                             HMDB0000254    0.004502  https://pubmed.ncbi.nlm.nih.gov/?term=Succinate+Phenylketonuria
#      4. L-Alanine                                             HMDB0000161    0.003724  https://pubmed.ncbi.nlm.nih.gov/?term=L-Alanine+Phenylketonuria
#      5. L-Aspartate                                           HMDB0062186    0.003478  https://pubmed.ncbi.nlm.nih.gov/?term=L-Aspartate+Phenylketonuria
#      6. L-Tryptophan                                          HMDB0000929    0.003434  https://pubmed.ncbi.nlm.nih.gov/?term=L-Tryptophan+Phenylketonuria
#      7. L Kynurenine C10H12N2O3                               HMDB0000684    0.003281  https://pubmed.ncbi.nlm.nih.gov/?term=L+Kynurenine+C10H12N2O3+Phenylketonuria
#      8. Pyruvate                                              HMDB0000243    0.003055  https://pubmed.ncbi.nlm.nih.gov/?term=Pyruvate+Phenylketonuria
#      9. 4 Fumarylacetoacetate C8H6O6                          HMDB0001268    0.003035  https://pubmed.ncbi.nlm.nih.gov/?term=4+Fumarylacetoacetate+C8H6O6+Phenylketonuria
#     10. L-Cysteine                                            HMDB0000574    0.002881  https://pubmed.ncbi.nlm.nih.gov/?term=L-Cysteine+Phenylketonuria
#     11. L-Asparagine                                          HMDB0000168    0.002854  https://pubmed.ncbi.nlm.nih.gov/?term=L-Asparagine+Phenylketonuria
#     12. L-Threonine                                           HMDB0000167    0.002540  https://pubmed.ncbi.nlm.nih.gov/?term=L-Threonine+Phenylketonuria
#     13. L-Leucine                                             HMDB0000687    0.002497  https://pubmed.ncbi.nlm.nih.gov/?term=L-Leucine+Phenylketonuria
#     14. L-Histidine                                           HMDB0000177    0.002382  https://pubmed.ncbi.nlm.nih.gov/?term=L-Histidine+Phenylketonuria
#     15. Formate                                               HMDB0000142    0.002379  https://pubmed.ncbi.nlm.nih.gov/?term=Formate+Phenylketonuria
#     16. L-Serine                                              HMDB0000589    0.002294  https://pubmed.ncbi.nlm.nih.gov/?term=L-Serine+Phenylketonuria
#     17. Tetrahydrobiopterin-4a-carbinolamine                                 0.002176  https://pubmed.ncbi.nlm.nih.gov/?term=Tetrahydrobiopterin-4a-carbinolamine+Phenylketonuria
#     18. Tyrosyl-Phenylalanyl-Tyrosine                                        0.002090  https://pubmed.ncbi.nlm.nih.gov/?term=Tyrosyl-Phenylalanyl-Tyrosine+Phenylketonuria
#     19. Phenylalanyl-Tyrosine                                                0.002090  https://pubmed.ncbi.nlm.nih.gov/?term=Phenylalanyl-Tyrosine+Phenylketonuria
#     20. (R)-3-Hydroxybutanoate                                HMDB0000011    0.001845  https://pubmed.ncbi.nlm.nih.gov/?term=(R)-3-Hydroxybutanoate+Phenylketonuria
#
#   → Verify each prediction at the PubMed links above.
#     Fill tier/pmid/direct_quote columns in the output CSV.
#
# =================================================================
# Saved: /content/drive/MyDrive/CTQW for metabolites/results/biological_interpretability.csv
# Total predictions: 80 (4 diseases × 20)
#
# NEXT STEPS for literature validation:
#   1. Open biological_interpretability.csv
#   2. For each row: click pubmed_search link
#   3. Find paper measuring this metabolite in this disease
#   4. Fill columns:
#        tier         → ESTABLISHED / POTENTIAL / NOVEL
#        pmid         → e.g. 25612837
#        direct_quote → exact sentence from paper
#        notes        → any additional context
# =================================================================
# Done.

# %%
# !python /content/project/experiments/05_supplementary.py
# Out:
# ── Supplementary S1: γ grid search ──
#   CSV not found — running experiment first...
# Setup pipeline...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:39<00:00, 1243.83it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#   HMDB+CTD: 171, SMPDB: 167
# CTQW/HMDB+CTD: 100% 171/171 [13:31<00:00,  4.75s/it]
# CTQW/SMPDB: 100% 167/167 [10:56<00:00,  3.93s/it]
#   γ=10... 92.2s
# NH(γ=10)/HMDB+CTD: 100% 171/171 [01:41<00:00,  1.69it/s]
# NH(γ=10)/SMPDB: 100% 167/167 [01:26<00:00,  1.93it/s]
#   γ=15... 92.0s
# NH(γ=15)/HMDB+CTD: 100% 171/171 [01:42<00:00,  1.67it/s]
# NH(γ=15)/SMPDB: 100% 167/167 [01:24<00:00,  1.97it/s]
#   γ=22... 90.4s
# NH(γ=22)/HMDB+CTD: 100% 171/171 [01:42<00:00,  1.66it/s]
# NH(γ=22)/SMPDB: 100% 167/167 [01:24<00:00,  1.97it/s]
#   γ=30... 90.6s
# NH(γ=30)/HMDB+CTD: 100% 171/171 [01:42<00:00,  1.66it/s]
# NH(γ=30)/SMPDB: 100% 167/167 [01:26<00:00,  1.93it/s]
#   γ=40... 92.6s
# NH(γ=40)/HMDB+CTD: 100% 171/171 [01:42<00:00,  1.67it/s]
# NH(γ=40)/SMPDB: 100% 167/167 [01:26<00:00,  1.93it/s]
#   γ=50... 92.4s
# NH(γ=50)/HMDB+CTD: 100% 171/171 [01:40<00:00,  1.70it/s]
# NH(γ=50)/SMPDB: 100% 167/167 [01:26<00:00,  1.94it/s]
#   γ=60... 93.4s
# NH(γ=60)/HMDB+CTD: 100% 171/171 [01:43<00:00,  1.65it/s]
# NH(γ=60)/SMPDB: 100% 167/167 [01:26<00:00,  1.92it/s]
#   γ=80... 93.5s
# NH(γ=80)/HMDB+CTD: 100% 171/171 [01:45<00:00,  1.63it/s]
# NH(γ=80)/SMPDB: 100% 167/167 [01:27<00:00,  1.90it/s]
#   γ=150... 92.7s
# NH(γ=150)/HMDB+CTD: 100% 171/171 [01:43<00:00,  1.65it/s]
# NH(γ=150)/SMPDB: 100% 167/167 [01:27<00:00,  1.90it/s]
#   γ=349... 93.2s
# NH(γ=349)/HMDB+CTD: 100% 171/171 [01:44<00:00,  1.64it/s]
# NH(γ=349)/SMPDB: 100% 167/167 [01:27<00:00,  1.90it/s]
#
#   [HMDB+CTD]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.0621   (baseline, γ→∞)
#       10     0.0651
#       15     0.0651
#       22     0.0659  ← paper (γ=k̄)
#       30     0.0662
#       40     0.0662
#       50     0.0663
#       60     0.0661
#       80     0.0659
#      150     0.0656
#      349     0.0637
#
#   [SMPDB]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.1714   (baseline, γ→∞)
#       10     0.2121
#       15     0.2188
#       22     0.2246  ← paper (γ=k̄)
#       30     0.2223
#       40     0.2217
#       50     0.2263
#       60     0.2275
#       80     0.2247
#      150     0.2255
#      349     0.2252
#
# ── Supplementary S2: t grid search ──
#   CSV not found — running experiment first...
# Setup pipeline...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:43<00:00, 1118.87it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20244 → 3240 → 362 → 215
#   HMDB+CTD: 171, SMPDB: 167
# CTQW-PRO(t=0.05)/HMDB+CTD: 100% 171/171 [12:13<00:00,  4.29s/it]
# CTQW-PRO(t=0.1)/HMDB+CTD: 100% 171/171 [12:16<00:00,  4.31s/it]
# CTQW-PRO(t=0.2)/HMDB+CTD: 100% 171/171 [12:25<00:00,  4.36s/it]
# CTQW-PRO(t=0.5)/HMDB+CTD: 100% 171/171 [13:15<00:00,  4.65s/it]
# CTQW-PRO(t=0.8)/HMDB+CTD: 100% 171/171 [12:30<00:00,  4.39s/it]
#
#   [CTQW-PRO, HMDB+CTD]       t        MRR
#   ------------------------
#     0.05     0.0378
#      0.1     0.0621  ← selected
#      0.2     0.0437
#      0.5     0.0431
#      0.8     0.0279
